# %% [markdown]
# ## Identify existing anomalies from Rotary Wing dataset

# %%
import pandas as pd
import os

# %%
os.chdir('D:/GMU/1 Spring-2021/DAEN-690/Project/Dataset')

# %%
# Read rotary wing .csv file
rw_df = pd.read_csv('RW_with_airports(29Nov2020-2Mar2021 revised).csv', header='infer')
rw_df.head(5)
# Out:
#   tail_number       date aircraft                       origin  \
# 0      N101AE  20-Feb-21      B06  Indy South Greenwood (KHFY)
# 1      N101AE  20-Feb-21      B06           Owens Field (II29)
# 2      N101AE  19-Feb-21      B06   Eagle Creek Airpark (KEYE)
# 3      N101AE  19-Feb-21      B06              Terre Haute, IN
# 4      N101AE  16-Feb-21      B06              Terre Haute, IN
#
#                                   origin_location  \
# 0  Indy South Greenwood (Indianapolis, IN) - KHFY
# 1            Owens Field (Greencastle, IN) - II29
# 2   Eagle Creek Airpark (Indianapolis, IN) - KEYE
# 3                            L 39.24110 -87.12544
# 4                            L 39.26091 -87.10094
#
#                    destination  \
# 0      Sanders Gyroport (IN88)
# 1  Indy South Greenwood (KHFY)
# 2              Greencastle, IN
# 3   Eagle Creek Airpark (KEYE)
# 4             Indianapolis, IN
#
#                              destination_location    departure  \
# 0        Sanders Gyroport (Cloverdale, IN) - IN88  03:56PM EST
# 1  Indy South Greenwood (Indianapolis, IN) - KHFY  03:01PM EST
# 2                            L 39.61981 -86.70046  02:38PM EST
# 3   Eagle Creek Airpark (Indianapolis, IN) - KEYE  12:30PM EST
# 4                            L 39.71667 -86.38333  01:51PM EST
#
#            arrival duration  ... STATE_NAME_origin  origin_state  \
# 0  04:15PM EST (?)     0:18  ...           Indiana            IN
# 1      03:21PM EST     0:20  ...           Indiana            IN
# 2      02:50PM EST     0:11  ...           Indiana            IN
# 3      02:11PM EST     1:40  ...           Indiana            IN
# 4      03:48PM EST     1:56  ...           Indiana            IN
#
#    ICAO_code_destination  iata_code_destination  AIRPORT_CODE_destination  \
# 0                   IN88                    IN7                       IN7
# 1                   KHFY                    IN7                       IN7
# 2                    NaN                    IN7                       IN7
# 3                   KEYE                    IN4                       IN4
# 4                   KIND                    IND                       IND
#
#      AIRPORT_NAME_destination CITY_NAME_destination COUNTRY_NAME_destination  \
# 0         Greenwood Municipal     Indianapolis - IN            United States
# 1        Indy South Greenwood     Indianapolis - IN            United States
# 2         Greenwood Municipal     Indianapolis - IN            United States
# 3         Eagle Creek Airpark     Indianapolis - IN            United States
# 4  Indianapolis International     Indianapolis - IN            United States
#
#   STATE_NAME_destination destination_state
# 0                Indiana                IN
# 1                Indiana                IN
# 2                Indiana                IN
# 3                Indiana                IN
# 4                Indiana                IN
#
# [5 rows x 31 columns]

# %%
rw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116292 entries, 0 to 116291
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   tail_number               116292 non-null  object
#  1   date                      116292 non-null  object
#  2   aircraft                  110178 non-null  object
#  3   origin                    116291 non-null  object
#  4   origin_location           116291 non-null  object
#  5   destination               116209 non-null  object
#  6   destination_location      116209 non-null  object
#  7   departure                 116292 non-null  object
#  8   arrival                   116096 non-null  object
#  9   duration                  116060 non-null  object
#  10  NAME                      116292 non-null  object
#  11  origin_Latitude           107183 non-null  float64
#  12  origin_Longitude          107183 non-null  float64
#  13  destination_Latitude      107173 non-null  float64
#  14  destination_Longitude     107173 non-null  float64
#  15  ICAO_code_origin          107789 non-null  object
#  16  iata_code_origin          111796 non-null  object
#  17  AIRPORT_CODE_origin       111117 non-null  object
#  18  AIRPORT_NAME_origin       111117 non-null  object
#  19  CITY_NAME_origin          111117 non-null  object
#  20  COUNTRY_NAME_origin       111117 non-null  object
#  21  STATE_NAME_origin         111117 non-null  object
#  22  origin_state              115536 non-null  object
#  23  ICAO_code_destination     108711 non-null  object
#  24  iata_code_destination     111788 non-null  object
#  25  AIRPORT_CODE_destination  110940 non-null  object
#  26  AIRPORT_NAME_destination  110940 non-null  object
#  27  CITY_NAME_destination     110940 non-null  object
#  28  COUNTRY_NAME_destination  110940 non-null  object
#  29  STATE_NAME_destination    110940 non-null  object
#  30  destination_state         115466 non-null  object
# dtypes: float64(4), object(27)
# memory usage: 27.5+ MB

# %%
# Check count of duplicate values for rotary wing dataset
rw_df.isna().sum()
# Out:
# tail_number                    0
# date                           0
# aircraft                    6114
# origin                         1
# origin_location                1
# destination                   83
# destination_location          83
# departure                      0
# arrival                      196
# duration                     232
# NAME                           0
# origin_Latitude             9109
# origin_Longitude            9109
# destination_Latitude        9119
# destination_Longitude       9119
# ICAO_code_origin            8503
# iata_code_origin            4496
# AIRPORT_CODE_origin         5175
# AIRPORT_NAME_origin         5175
# CITY_NAME_origin            5175
# COUNTRY_NAME_origin         5175
# STATE_NAME_origin           5175
# origin_state                 756
# ICAO_code_destination       7581
# iata_code_destination       4504
# AIRPORT_CODE_destination    5352
# AIRPORT_NAME_destination    5352
# CITY_NAME_destination       5352
# COUNTRY_NAME_destination    5352
# STATE_NAME_destination      5352
# destination_state            826
# dtype: int64

# %%
# Create a new dataframe with attributes tail_number, ICAO_code_origin, ICAO_code_destination
new_df = rw_df[['tail_number','ICAO_code_origin', 'ICAO_code_destination']]

# %%
# Check count of null values
new_df.isna().sum()
# Out:
# tail_number                 0
# ICAO_code_origin         8503
# ICAO_code_destination    7581
# dtype: int64

# %%
# Drop null values
new_df = new_df.dropna()

# %%
# Concat values and store in a new column Path
new_df['Path'] = new_df['ICAO_code_origin'] + new_df['ICAO_code_destination']

# %%
new_df
# Out:
#        tail_number ICAO_code_origin ICAO_code_destination      Path
# 0           N101AE             KHFY                  IN88  KHFYIN88
# 1           N101AE             II29                  KHFY  II29KHFY
# 3           N101AE             KHUF                  KEYE  KHUFKEYE
# 4           N101AE             KHUF                  KIND  KHUFKIND
# 6           N101AE             05IN                  KIND  05INKIND
# ...            ...              ...                   ...       ...
# 116285      N135MH             KFME                  KDCA  KFMEKDCA
# 116286      N135MH              2W5                  KFME   2W5KFME
# 116287      N135MH              2W5                   2W5    2W52W5
# 116288      N135MH              2W5                   2W5    2W52W5
# 116289      N135MH              2W5                  KDCA   2W5KDCA
#
# [102264 rows x 4 columns]

# %%
# Get total count of each Path 
res = pd.DataFrame(new_df.Path.value_counts().sort_values(ascending=True)).rename(columns={"Path":"PathFreq"}).reset_index()
res
# Out:
#           index  PathFreq
# 0       29DKBFD         1
# 1      KAKRKCLE         1
# 2      KGMUKSPA         1
# 3       N45KDXR         1
# 4      KDUGKCGZ         1
# ...         ...       ...
# 16285  KGLSKGLS       474
# 16286  KABQKABQ       519
# 16287  KBADKHUM       573
# 16288  KHUMKBAD       582
# 16289  KHUMKHUM      2074
#
# [16290 rows x 2 columns]

# %%
# Check if duplicates
res.duplicated().sum()
# Out:
# 0

# %%
# Join 'res' dataframe with 'new_df' dataframe based on Path and index
new_df2 = new_df.merge(res, how='left', left_on='Path', right_on='index')
new_df2
# Out:
#        tail_number ICAO_code_origin ICAO_code_destination      Path     index  \
# 0           N101AE             KHFY                  IN88  KHFYIN88  KHFYIN88
# 1           N101AE             II29                  KHFY  II29KHFY  II29KHFY
# 2           N101AE             KHUF                  KEYE  KHUFKEYE  KHUFKEYE
# 3           N101AE             KHUF                  KIND  KHUFKIND  KHUFKIND
# 4           N101AE             05IN                  KIND  05INKIND  05INKIND
# ...            ...              ...                   ...       ...       ...
# 102259      N135MH             KFME                  KDCA  KFMEKDCA  KFMEKDCA
# 102260      N135MH              2W5                  KFME   2W5KFME   2W5KFME
# 102261      N135MH              2W5                   2W5    2W52W5    2W52W5
# 102262      N135MH              2W5                   2W5    2W52W5    2W52W5
# 102263      N135MH              2W5                  KDCA   2W5KDCA   2W5KDCA
#
#         PathFreq
# 0              1
# 1              1
# 2              1
# 3              3
# 4              1
# ...          ...
# 102259        22
# 102260         4
# 102261         6
# 102262         6
# 102263         4
#
# [102264 rows x 6 columns]

# %%
# Store dataframe in a csv file
new_df2.to_csv('D:/GMU/1 Spring-2021/DAEN-690/Project/Dataset/RW_anomaly.csv')
