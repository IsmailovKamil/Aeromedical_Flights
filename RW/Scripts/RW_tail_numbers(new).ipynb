# %%
#load packages
import pandas as pd 
import numpy as np
import fuzzymatcher
pd.set_option('display.max_columns', 999)

# %%
#load data and convert dates to datetime
rw = pd.read_csv("../Datasets/RW_tail_numbers.csv")
rw.head()
# Out:
#   tail_number         date aircraft                       origin  \
# 0      N101AE  20-Feb-2021      B06  Indy South Greenwood (KHFY)
# 1      N101AE  20-Feb-2021      B06             Owens Fld (II29)
# 2      N101AE  19-Feb-2021      B06   Eagle Creek Airpark (KEYE)
# 3      N101AE  19-Feb-2021      B06         Near Terre Haute, IN
# 4      N101AE  16-Feb-2021      B06         Near Terre Haute, IN
#
#                                   origin_location  \
# 0  Indy South Greenwood (Indianapolis, IN) - KHFY
# 1              Owens Fld (Greencastle, IN) - II29
# 2   Eagle Creek Airpark (Indianapolis, IN) - KEYE
# 3                            L 39.24110 -87.12544
# 4                            L 39.26091 -87.10094
#
#                    destination  \
# 0      Sanders Gyroport (IN88)
# 1  Indy South Greenwood (KHFY)
# 2         Near Greencastle, IN
# 3   Eagle Creek Airpark (KEYE)
# 4        Near Indianapolis, IN
#
#                              destination_location               departure  \
# 0        Sanders Gyroport (Cloverdale, IN) - IN88             03:56PM EST
# 1  Indy South Greenwood (Indianapolis, IN) - KHFY             03:01PM EST
# 2                            L 39.61981 -86.70046             02:38PM EST
# 3   Eagle Creek Airpark (Indianapolis, IN) - KEYE  First seen 12:30PM EST
# 4                            L 39.71667 -86.38333  First seen 01:51PM EST
#
#                  arrival duration TailNumber  \
# 0        04:15PM EST (?)     0:18     N101AE
# 1            03:21PM EST     0:20     N101AE
# 2  Last seen 02:50PM EST     0:11     N101AE
# 3            02:11PM EST     1:40     N101AE
# 4  Last seen 03:48PM EST     1:56     N101AE
#
#                                                 NAME
# 0  AIR EVAC EMS INC                              ...
# 1  AIR EVAC EMS INC                              ...
# 2  AIR EVAC EMS INC                              ...
# 3  AIR EVAC EMS INC                              ...
# 4  AIR EVAC EMS INC                              ...

# %%
rw.shape
# Out:
# (116292, 12)

# %%
# Remove useless words
rw = rw.replace(regex={'Near ':'', 'First seen ':'', 'Last seen ':'', 'En Route':None, 'Unknown':None, 'Diverted':None})

# %%
# check for duplicates
rw.duplicated().sum()
# Out:
# 0

# %%
# check for null values
rw.isna().sum()
# Out:
# tail_number                0
# date                       0
# aircraft                6114
# origin                     1
# origin_location            1
# destination               83
# destination_location      83
# departure                  0
# arrival                  194
# duration                 232
# TailNumber                 0
# NAME                       0
# dtype: int64

# %%
# split origin_Latitude and origin_Longitude
rw['origin_Latitude'] = rw[rw.origin_location.str.startswith('L ', na=False)].origin_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[0]
rw['origin_Longitude'] = rw[rw.origin_location.str.startswith('L ', na=False)].origin_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[1]

# %%
# split destination_Latitude and destination_Longitude
rw['destination_Latitude'] = rw[rw.destination_location.str.startswith('L ', na=False)].destination_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[0]
rw['destination_Longitude'] = rw[rw.destination_location.str.startswith('L ', na=False)].destination_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[1]

# %%
# convert to numeric
rw['origin_Latitude'] = pd.to_numeric(rw.origin_Latitude, errors='coerce')
rw['origin_Longitude'] = pd.to_numeric(rw.origin_Longitude, errors='coerce')

rw['destination_Latitude'] = pd.to_numeric(rw.destination_Latitude, errors='coerce')
rw['destination_Longitude'] = pd.to_numeric(rw.destination_Longitude, errors='coerce')

# %%
# split ICAO_code
rw['ICAO_code_origin'] = rw[rw.origin_Latitude.isna()].origin_location.str.rsplit(" - ", n = 1, expand = True)[1]
rw['ICAO_code_destination'] = rw[rw.destination_Latitude.isna()].destination_location.str.rsplit(" - ", n = 1, expand = True)[1]

# %%
rw.head()
# Out:
#   tail_number         date aircraft                       origin  \
# 0      N101AE  20-Feb-2021      B06  Indy South Greenwood (KHFY)
# 1      N101AE  20-Feb-2021      B06             Owens Fld (II29)
# 2      N101AE  19-Feb-2021      B06   Eagle Creek Airpark (KEYE)
# 3      N101AE  19-Feb-2021      B06              Terre Haute, IN
# 4      N101AE  16-Feb-2021      B06              Terre Haute, IN
#
#                                   origin_location  \
# 0  Indy South Greenwood (Indianapolis, IN) - KHFY
# 1              Owens Fld (Greencastle, IN) - II29
# 2   Eagle Creek Airpark (Indianapolis, IN) - KEYE
# 3                            L 39.24110 -87.12544
# 4                            L 39.26091 -87.10094
#
#                    destination  \
# 0      Sanders Gyroport (IN88)
# 1  Indy South Greenwood (KHFY)
# 2              Greencastle, IN
# 3   Eagle Creek Airpark (KEYE)
# 4             Indianapolis, IN
#
#                              destination_location    departure  \
# 0        Sanders Gyroport (Cloverdale, IN) - IN88  03:56PM EST
# 1  Indy South Greenwood (Indianapolis, IN) - KHFY  03:01PM EST
# 2                            L 39.61981 -86.70046  02:38PM EST
# 3   Eagle Creek Airpark (Indianapolis, IN) - KEYE  12:30PM EST
# 4                            L 39.71667 -86.38333  01:51PM EST
#
#            arrival duration TailNumber  \
# 0  04:15PM EST (?)     0:18     N101AE
# 1      03:21PM EST     0:20     N101AE
# 2      02:50PM EST     0:11     N101AE
# 3      02:11PM EST     1:40     N101AE
# 4      03:48PM EST     1:56     N101AE
#
#                                                 NAME  origin_Latitude  \
# 0  AIR EVAC EMS INC                              ...              NaN
# 1  AIR EVAC EMS INC                              ...              NaN
# 2  AIR EVAC EMS INC                              ...              NaN
# 3  AIR EVAC EMS INC                              ...         39.24110
# 4  AIR EVAC EMS INC                              ...         39.26091
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0               NaN                   NaN                    NaN
# 1               NaN                   NaN                    NaN
# 2               NaN              39.61981              -86.70046
# 3         -87.12544                   NaN                    NaN
# 4         -87.10094              39.71667              -86.38333
#
#   ICAO_code_origin ICAO_code_destination
# 0             KHFY                  IN88
# 1             II29                  KHFY
# 2             KEYE                   NaN
# 3              NaN                  KEYE
# 4              NaN                   NaN

# %%
# load airport code data
airport_codes = pd.read_csv("..//Datasets/Airports/airport-codes.csv")
airport_codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %%
# check duplicates
airport_codes.duplicated().sum()
# Out:
# 0

# %%
# split coordinates and convert to numeric
airport_codes["Latitude"] = pd.to_numeric(airport_codes.coordinates.str.split(', ', n=1, expand=True)[1])
airport_codes["Longitude"] = pd.to_numeric(airport_codes.coordinates.str.split(', ', n=1, expand=True)[0])

# %%
# merge origin airport information
rw = rw.merge(airport_codes[['ident', 'iata_code', 'Latitude', 'Longitude']].add_suffix('_origin'),
         how='left', left_on='ICAO_code_origin', right_on='ident_origin')

# %%
# merge destination airport information
rw = rw.merge(airport_codes[['ident', 'iata_code', 'Latitude', 'Longitude']].add_suffix('_destination'),
         how='left', left_on='ICAO_code_destination', right_on='ident_destination')

# %%
# merge 2 columns
rw.origin_Latitude = rw.origin_Latitude.fillna(0) + rw.Latitude_origin.fillna(0)
rw.origin_Longitude = rw.origin_Longitude.fillna(0) + rw.Longitude_origin.fillna(0)

rw.destination_Latitude = rw.destination_Latitude.fillna(0) + rw.Latitude_destination.fillna(0)
rw.destination_Longitude = rw.destination_Longitude.fillna(0) + rw.Longitude_destination.fillna(0)

# drop duplicated columns
rw = rw.drop(['ident_origin', 'ident_destination', 'Latitude_origin', 'Longitude_origin', 'Latitude_destination', 'Longitude_destination'], axis=1)

# %%
# load airport data
airports = pd.read_csv("..//Datasets/Airports/BTS_Airports_LAT_LON.csv")

# %%
airports.head()
# Out:
#   AIRPORT_CODE             AIRPORT_NAME              CITY_NAME   COUNTRY_NAME  \
# 0          01A     Afognak Lake Airport      Afognak Lake - AK  United States
# 1          03A  Bear Creek Mining Strip  Granite Mountain - AK  United States
# 2          04A          Lik Mining Camp               Lik - AK  United States
# 3          05A     Little Squaw Airport      Little Squaw - AK  United States
# 4          06A             Kizhuyak Bay          Kizhuyak - AK  United States
#
#   STATE_NAME STATE_CODE   LATITUDE   LONGITUDE
# 0     Alaska         AK  58.109444 -152.906667
# 1     Alaska         AK  65.548056 -161.071667
# 2     Alaska         AK  68.083333 -163.166667
# 3     Alaska         AK  67.570000 -148.183889
# 4     Alaska         AK  57.745278 -152.882778

# %%
airports = airports.loc[airports.LONGITUDE < 0]

# %%
# replace abbreviations to full name for the best matching
rw = rw.replace(regex={r'Muni': 'Municipal', r'Rgnl':'Regional', r'Intl':'International', r"Int'l":'International',
                 r'Trml':'Terminal', r'Fld':'Field'})

# split states fot the best matching
rw['origin_state'] = rw.origin.str.split(', ', n=1, expand=True)[1]
rw['destination_state'] = rw.destination.str.split(', ', n=1, expand=True)[1]

# %%
rw
# Out:
#        tail_number         date aircraft                       origin  \
# 0           N101AE  20-Feb-2021      B06  Indy South Greenwood (KHFY)
# 1           N101AE  20-Feb-2021      B06           Owens Field (II29)
# 2           N101AE  19-Feb-2021      B06   Eagle Creek Airpark (KEYE)
# 3           N101AE  19-Feb-2021      B06              Terre Haute, IN
# 4           N101AE  16-Feb-2021      B06              Terre Haute, IN
# ...            ...          ...      ...                          ...
# 116287      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116288      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116289      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116290      N135MH  29-Nov-2020     EC35               Washington, DC
# 116291      N135MH  29-Nov-2020     EC35               Washington, DC
#
#                                        origin_location  \
# 0       Indy South Greenwood (Indianapolis, IN) - KHFY
# 1                 Owens Field (Greencastle, IN) - II29
# 2        Eagle Creek Airpark (Indianapolis, IN) - KEYE
# 3                                 L 39.24110 -87.12544
# 4                                 L 39.26091 -87.10094
# ...                                                ...
# 116287                Maryland (Indian Head, MD) - 2W5
# 116288                Maryland (Indian Head, MD) - 2W5
# 116289                Maryland (Indian Head, MD) - 2W5
# 116290                            L 38.92861 -77.01709
# 116291                            L 38.92856 -77.01721
#
#                         destination  \
# 0           Sanders Gyroport (IN88)
# 1       Indy South Greenwood (KHFY)
# 2                   Greencastle, IN
# 3        Eagle Creek Airpark (KEYE)
# 4                  Indianapolis, IN
# ...                             ...
# 116287               Maryland (2W5)
# 116288               Maryland (2W5)
# 116289       Reagan National (KDCA)
# 116290               Maryland (2W5)
# 116291                   Lee (KANP)
#
#                                   destination_location    departure  \
# 0             Sanders Gyroport (Cloverdale, IN) - IN88  03:56PM EST
# 1       Indy South Greenwood (Indianapolis, IN) - KHFY  03:01PM EST
# 2                                 L 39.61981 -86.70046  02:38PM EST
# 3        Eagle Creek Airpark (Indianapolis, IN) - KEYE  12:30PM EST
# 4                                 L 39.71667 -86.38333  01:51PM EST
# ...                                                ...          ...
# 116287                Maryland (Indian Head, MD) - 2W5  09:46PM EST
# 116288                Maryland (Indian Head, MD) - 2W5  05:02PM EST
# 116289         Reagan National (Washington, DC) - KDCA  02:43PM EST
# 116290                Maryland (Indian Head, MD) - 2W5  10:12PM EST
# 116291                      Lee (Annapolis, MD) - KANP  07:50PM EST
#
#                 arrival duration TailNumber  \
# 0       04:15PM EST (?)     0:18     N101AE
# 1           03:21PM EST     0:20     N101AE
# 2           02:50PM EST     0:11     N101AE
# 3           02:11PM EST     1:40     N101AE
# 4           03:48PM EST     1:56     N101AE
# ...                 ...      ...        ...
# 116287      10:39PM EST     0:53     N135MH
# 116288  05:02PM EST (?)     0:00     N135MH
# 116289      04:28PM EST     1:45     N135MH
# 116290      10:35PM EST     0:22     N135MH
# 116291      09:21PM EST     1:30     N135MH
#
#                                                      NAME  origin_Latitude  \
# 0       AIR EVAC EMS INC                              ...        39.628399
# 1       AIR EVAC EMS INC                              ...        39.610901
# 2       AIR EVAC EMS INC                              ...        39.830700
# 3       AIR EVAC EMS INC                              ...        39.241100
# 4       AIR EVAC EMS INC                              ...        39.260910
# ...                                                   ...              ...
# 116287  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116288  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116289  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116290  WASHINGTON HOSPITAL CENTER                    ...        38.928610
# 116291  WASHINGTON HOSPITAL CENTER                    ...        38.928560
#
#         origin_Longitude  destination_Latitude  destination_Longitude  \
# 0             -86.087898             39.513401             -86.763901
# 1             -86.756104             39.628399             -86.087898
# 2             -86.294403             39.619810             -86.700460
# 3             -87.125440             39.830700             -86.294403
# 4             -87.100940             39.716670             -86.383330
# ...                  ...                   ...                    ...
# 116287          0.000000              0.000000               0.000000
# 116288          0.000000              0.000000               0.000000
# 116289          0.000000             38.852100             -77.037697
# 116290        -77.017090              0.000000               0.000000
# 116291        -77.017210             38.942902             -76.568398
#
#        ICAO_code_origin ICAO_code_destination iata_code_origin  \
# 0                  KHFY                  IN88              NaN
# 1                  II29                  KHFY              NaN
# 2                  KEYE                   NaN              NaN
# 3                   NaN                  KEYE              NaN
# 4                   NaN                   NaN              NaN
# ...                 ...                   ...              ...
# 116287              2W5                   2W5              NaN
# 116288              2W5                   2W5              NaN
# 116289              2W5                  KDCA              NaN
# 116290              NaN                   2W5              NaN
# 116291              NaN                  KANP              NaN
#
#        iata_code_destination origin_state destination_state
# 0                        NaN         None              None
# 1                        NaN         None              None
# 2                        NaN         None                IN
# 3                        NaN           IN              None
# 4                        NaN           IN                IN
# ...                      ...          ...               ...
# 116287                   NaN         None              None
# 116288                   NaN         None              None
# 116289                   DCA         None              None
# 116290                   NaN           DC              None
# 116291                   ANP           DC              None
#
# [116292 rows x 22 columns]

# %%
# fuzzy merge on locations with origin airports
rw = fuzzymatcher.fuzzy_left_join(rw, airports.add_suffix('_origin'), left_on = ['origin_state', 'origin_Latitude', 'origin_Longitude', 'origin'], 
                                  right_on = ['STATE_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin','AIRPORT_NAME_origin']).iloc[:,3:].reset_index(drop=True)

# %%
rw
# Out:
#        tail_number         date aircraft                       origin  \
# 0           N101AE  20-Feb-2021      B06  Indy South Greenwood (KHFY)
# 1           N101AE  20-Feb-2021      B06           Owens Field (II29)
# 2           N101AE  19-Feb-2021      B06   Eagle Creek Airpark (KEYE)
# 3           N101AE  19-Feb-2021      B06              Terre Haute, IN
# 4           N101AE  16-Feb-2021      B06              Terre Haute, IN
# ...            ...          ...      ...                          ...
# 116287      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116288      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116289      N135MH  30-Nov-2020     EC35               Maryland (2W5)
# 116290      N135MH  29-Nov-2020     EC35               Washington, DC
# 116291      N135MH  29-Nov-2020     EC35               Washington, DC
#
#                                        origin_location  \
# 0       Indy South Greenwood (Indianapolis, IN) - KHFY
# 1                 Owens Field (Greencastle, IN) - II29
# 2        Eagle Creek Airpark (Indianapolis, IN) - KEYE
# 3                                 L 39.24110 -87.12544
# 4                                 L 39.26091 -87.10094
# ...                                                ...
# 116287                Maryland (Indian Head, MD) - 2W5
# 116288                Maryland (Indian Head, MD) - 2W5
# 116289                Maryland (Indian Head, MD) - 2W5
# 116290                            L 38.92861 -77.01709
# 116291                            L 38.92856 -77.01721
#
#                         destination  \
# 0           Sanders Gyroport (IN88)
# 1       Indy South Greenwood (KHFY)
# 2                   Greencastle, IN
# 3        Eagle Creek Airpark (KEYE)
# 4                  Indianapolis, IN
# ...                             ...
# 116287               Maryland (2W5)
# 116288               Maryland (2W5)
# 116289       Reagan National (KDCA)
# 116290               Maryland (2W5)
# 116291                   Lee (KANP)
#
#                                   destination_location    departure  \
# 0             Sanders Gyroport (Cloverdale, IN) - IN88  03:56PM EST
# 1       Indy South Greenwood (Indianapolis, IN) - KHFY  03:01PM EST
# 2                                 L 39.61981 -86.70046  02:38PM EST
# 3        Eagle Creek Airpark (Indianapolis, IN) - KEYE  12:30PM EST
# 4                                 L 39.71667 -86.38333  01:51PM EST
# ...                                                ...          ...
# 116287                Maryland (Indian Head, MD) - 2W5  09:46PM EST
# 116288                Maryland (Indian Head, MD) - 2W5  05:02PM EST
# 116289         Reagan National (Washington, DC) - KDCA  02:43PM EST
# 116290                Maryland (Indian Head, MD) - 2W5  10:12PM EST
# 116291                      Lee (Annapolis, MD) - KANP  07:50PM EST
#
#                 arrival duration TailNumber  \
# 0       04:15PM EST (?)     0:18     N101AE
# 1           03:21PM EST     0:20     N101AE
# 2           02:50PM EST     0:11     N101AE
# 3           02:11PM EST     1:40     N101AE
# 4           03:48PM EST     1:56     N101AE
# ...                 ...      ...        ...
# 116287      10:39PM EST     0:53     N135MH
# 116288  05:02PM EST (?)     0:00     N135MH
# 116289      04:28PM EST     1:45     N135MH
# 116290      10:35PM EST     0:22     N135MH
# 116291      09:21PM EST     1:30     N135MH
#
#                                                      NAME  origin_Latitude  \
# 0       AIR EVAC EMS INC                              ...        79.256798
# 1       AIR EVAC EMS INC                              ...        79.221802
# 2       AIR EVAC EMS INC                              ...        79.661400
# 3       AIR EVAC EMS INC                              ...        39.241100
# 4       AIR EVAC EMS INC                              ...        39.260910
# ...                                                   ...              ...
# 116287  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116288  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116289  WASHINGTON HOSPITAL CENTER                    ...         0.000000
# 116290  WASHINGTON HOSPITAL CENTER                    ...        38.928610
# 116291  WASHINGTON HOSPITAL CENTER                    ...        38.928560
#
#         origin_Longitude  destination_Latitude  destination_Longitude  \
# 0            -172.175796             79.026802            -173.527802
# 1            -173.512207             79.256798            -172.175796
# 2            -172.588806             39.619810             -86.700460
# 3             -87.125440             79.661400            -172.588806
# 4             -87.100940             39.716670             -86.383330
# ...                  ...                   ...                    ...
# 116287          0.000000              0.000000               0.000000
# 116288          0.000000              0.000000               0.000000
# 116289          0.000000             77.704200            -154.075394
# 116290        -77.017090              0.000000               0.000000
# 116291        -77.017210             77.885804            -153.136796
#
#        ICAO_code_origin ICAO_code_destination iata_code_origin_x  \
# 0                  KHFY                  IN88                NaN
# 1                  II29                  KHFY                NaN
# 2                  KEYE                   NaN                NaN
# 3                   NaN                  KEYE                NaN
# 4                   NaN                   NaN                NaN
# ...                 ...                   ...                ...
# 116287              2W5                   2W5                NaN
# 116288              2W5                   2W5                NaN
# 116289              2W5                  KDCA                NaN
# 116290              NaN                   2W5                NaN
# 116291              NaN                  KANP                NaN
#
#        iata_code_destination_x iata_code_origin_y iata_code_destination_y  \
# 0                          NaN                NaN                     NaN
# 1                          NaN                NaN                     NaN
# 2                          NaN                NaN                     NaN
# 3                          NaN                NaN                     NaN
# 4                          NaN                NaN                     NaN
# ...                        ...                ...                     ...
# 116287                     NaN                NaN                     NaN
# 116288                     NaN                NaN                     NaN
# 116289                     DCA                NaN                     DCA
# 116290                     NaN                NaN                     NaN
# 116291                     ANP                NaN                     ANP
#
#        origin_state destination_state AIRPORT_CODE_origin  \
# 0              None              None                 IN7
# 1              None              None                 CUB
# 2              None                IN                 IN4
# 3                IN              None                 HUF
# 4                IN                IN                 HUF
# ...             ...               ...                 ...
# 116287         None              None                 MD2
# 116288         None              None                 MD2
# 116289         None              None                 MD2
# 116290           DC              None                 WAS
# 116291           DC              None                 WAS
#
#                     AIRPORT_NAME_origin   CITY_NAME_origin  \
# 0                  Indy South Greenwood  Indianapolis - IN
# 1                           Owens Field      Columbia - SC
# 2                   Eagle Creek Airpark  Indianapolis - IN
# 3                  Terre Haute Regional   Terre Haute - IN
# 4                  Terre Haute Regional   Terre Haute - IN
# ...                                 ...                ...
# 116287                         Maryland   Indian Head - MD
# 116288                         Maryland   Indian Head - MD
# 116289                         Maryland   Indian Head - MD
# 116290  Washington DC Metropolitan Area    Washington - DC
# 116291  Washington DC Metropolitan Area    Washington - DC
#
#        COUNTRY_NAME_origin     STATE_NAME_origin STATE_CODE_origin  \
# 0            United States               Indiana                IN
# 1            United States        South Carolina                SC
# 2            United States               Indiana                IN
# 3            United States               Indiana                IN
# 4            United States               Indiana                IN
# ...                    ...                   ...               ...
# 116287       United States              Maryland                MD
# 116288       United States              Maryland                MD
# 116289       United States              Maryland                MD
# 116290       United States  District of Columbia                DC
# 116291       United States  District of Columbia                DC
#
#         LATITUDE_origin  LONGITUDE_origin
# 0             39.627500        -86.088056
# 1             33.970833        -80.995556
# 2             39.830833        -86.294444
# 3             39.450556        -87.306944
# 4             39.450556        -87.306944
# ...                 ...               ...
# 116287        38.600556        -77.073056
# 116288        38.600556        -77.073056
# 116289        38.600556        -77.073056
# 116290        38.883333        -77.033333
# 116291        38.883333        -77.033333
#
# [116292 rows x 32 columns]

# %%
# replace null values in iata_code_origin
rw.loc[rw.iata_code_origin.isna(),'iata_code_origin']  = rw.loc[rw.iata_code_origin.isna(), 'AIRPORT_CODE_origin']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-2811bd0301da> in <module>
#       1 # replace null values in iata_code_origin
# ----> 2 rw.loc[rw.iata_code_origin.isna(),'iata_code_origin']  = rw.loc[rw.iata_code_origin.isna(), 'AIRPORT_CODE_origin']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iata_code_origin'

# %%
# fuzzy merge on locations with destination airports
rw = fuzzymatcher.fuzzy_left_join(rw, airports.add_suffix('_destination'), left_on = ['destination_state', 'destination_Latitude', 'destination_Longitude', 'destination'], 
                                  right_on = ['STATE_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination','AIRPORT_NAME_destination']).iloc[:,3:].reset_index(drop=True)

# %%
# replace null values in iata_code_destination
rw.loc[rw.iata_code_destination.isna(),'iata_code_destination']  = rw.loc[rw.iata_code_destination.isna(), 'AIRPORT_CODE_destination']

# %%
# drop duplicated rows
rw = rw.drop(['destination_state', 'AIRPORT_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination'], axis=1)
rw = rw.drop(['origin_state', 'AIRPORT_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin'], axis=1)
rw.iloc[[0,1373], -5:] = None
rw.loc[rw.origin_Longitude > 0] = rw.loc[rw.origin_Longitude > 0].drop(5463, axis=0)

# %%
# complete ICAO codes 
rw.loc[rw.ICAO_code_origin.isna(), 'ICAO_code_origin'] = rw.merge(airport_codes[['iata_code','ident']], how='left', left_on='iata_code_origin', right_on='iata_code').ident
rw.loc[rw.ICAO_code_destination.isna(), 'ICAO_code_destination'] = rw.merge(airport_codes[['iata_code','ident']], how='left', left_on='iata_code_destination', right_on='iata_code').ident

# %%
rw.head()
# Out:
#   tail_number         date aircraft             origin  \
# 0      N7025P  28-Feb-2021     None           Bend, OR
# 1      N7025P  28-Feb-2021     None  Tews Field (CA53)
# 2      N7025P  21-Feb-2021     None        Lincoln, CA
# 3      N7025P  21-Feb-2021     None      Red Bluff, CA
# 4      N7025P  24-Dec-2020     None      Red Bluff, CA
#
#                    origin_location               destination  \
# 0            L 43.95194 -121.28694                       NaN
# 1  Tews Field (Redding, CA) - CA53                  Bend, OR
# 2            L 38.93333 -121.41667  Redding Municipal (KRDD)
# 3            L 40.24000 -122.19083            Marysville, CA
# 4            L 40.28861 -122.05861          Emigrant Gap, CA
#
#                      destination_location    departure      arrival duration  \
# 0                                    None  04:59PM PST          NaN     None
# 1                   L 43.81944 -121.37583  01:36PM PST  03:01PM PST     1:24
# 2  Redding Municipal (Redding, CA) - KRDD  03:02PM PST  03:49PM PST     0:47
# 3                   L 38.94750 -121.52250  12:46PM PST  01:20PM PST     0:33
# 4                   L 39.77972 -120.52333  09:25AM PST  10:02AM PST     0:36
#
#                                      medical_service  origin_Latitude  \
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...        43.951940
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...        40.672501
# 2  A PRECIOUS LIFE FLIGHT LLC                    ...        38.933330
# 3  A PRECIOUS LIFE FLIGHT LLC                    ...        40.240000
# 4  A PRECIOUS LIFE FLIGHT LLC                    ...        40.288610
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0       -121.286940              0.000000               0.000000
# 1       -122.342003             43.819440            -121.375830
# 2       -121.416670             40.508999            -122.292999
# 3       -122.190830             38.947500            -121.522500
# 4       -122.058610             39.779720            -120.523330
#
#   ICAO_code_origin ICAO_code_destination iata_code_origin  \
# 0              NaN                  LFRK              OR4
# 1             CA53                   NaN              O85
# 2             KSMF                  KRDD              SMF
# 3             KRBL                  KSMF              RBL
# 4             KRBL                   NaN              RBL
#
#   iata_code_destination       AIRPORT_NAME_origin CITY_NAME_origin  \
# 0                   CFR            Bend Municipal        Bend - OR
# 1                   OR4              Benton Field     Redding - CA
# 2                   RDD  Sacramento International  Sacramento - CA
# 3                   SMF       Red Bluff Municipal   Red Bluff - CA
# 4                   FVP       Red Bluff Municipal   Red Bluff - CA
#
#   COUNTRY_NAME_origin STATE_NAME_origin STATE_CODE_origin  \
# 0       United States            Oregon                OR
# 1       United States        California                CA
# 2       United States        California                CA
# 3       United States        California                CA
# 4       United States        California                CA
#
#    AIRPORT_NAME_destination CITY_NAME_destination COUNTRY_NAME_destination  \
# 0                      None                  None                     None
# 1            Bend Municipal             Bend - OR            United States
# 2         Redding Municipal          Redding - CA            United States
# 3  Sacramento International       Sacramento - CA            United States
# 4             Gansner Field           Quincy - CA            United States
#
#   STATE_NAME_destination STATE_CODE_destination
# 0                   None                   None
# 1                 Oregon                     OR
# 2             California                     CA
# 3             California                     CA
# 4             California                     CA

# %%
#rw.to_csv('..//Datasets/rw_with_airports.csv', index=False)
