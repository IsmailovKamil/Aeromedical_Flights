# %% [markdown]
# ## Identify existing anomalies from Fixed Wing dataset

# %%
import pandas as pd
import os

# %%
os.chdir('D:/GMU/1 Spring-2021/DAEN-690/Project/Dataset')

# %%
# Read fixed wing .csv file
fw_df = pd.read_csv('FW_with_airports(29Nov20-28Feb21 revised).csv', header='infer')
fw_df.head(5)
# Out:
#   tail_number       date aircraft             origin  \
# 0      N7025P  28-Feb-21      NaN           Bend, OR
# 1      N7025P  28-Feb-21      NaN  Tews Field (CA53)
# 2      N7025P  21-Feb-21      NaN        Lincoln, CA
# 3      N7025P  21-Feb-21      NaN      Red Bluff, CA
# 4      N7025P  24-Dec-20      NaN      Red Bluff, CA
#
#                    origin_location               destination  \
# 0            L 43.95194 -121.28694                       NaN
# 1  Tews Field (Redding, CA) - CA53                  Bend, OR
# 2            L 38.93333 -121.41667  Redding Municipal (KRDD)
# 3            L 40.24000 -122.19083            Marysville, CA
# 4            L 40.28861 -122.05861          Emigrant Gap, CA
#
#                      destination_location    departure      arrival duration  \
# 0                                     NaN  04:59PM PST          NaN      NaN
# 1                   L 43.81944 -121.37583  01:36PM PST  03:01PM PST     1:24
# 2  Redding Municipal (Redding, CA) - KRDD  03:02PM PST  03:49PM PST     0:47
# 3                   L 38.94750 -121.52250  12:46PM PST  01:20PM PST     0:33
# 4                   L 39.77972 -120.52333  09:25AM PST  10:02AM PST     0:36
#
#    ... COUNTRY_NAME_origin  STATE_NAME_origin  origin_state  \
# 0  ...       United States             Oregon            OR
# 1  ...       United States         California            CA
# 2  ...       United States         California            CA
# 3  ...       United States         California            CA
# 4  ...       United States         California            CA
#
#    ICAO_code_destination  iata_code_destination  AIRPORT_NAME_destination  \
# 0                    NaN                    NaN                       NaN
# 1                    NaN                    OR4            Bend Municipal
# 2                   KRDD                    RDD         Redding Municipal
# 3                   KSMF                    SMF  Sacramento International
# 4                    NaN                    NaN                       NaN
#
#   CITY_NAME_destination COUNTRY_NAME_destination STATE_NAME_destination  \
# 0                   NaN                      NaN                    NaN
# 1             Bend - OR            United States                 Oregon
# 2          Redding - CA            United States             California
# 3       Sacramento - CA            United States             California
# 4                   NaN                      NaN                    NaN
#
#   destination_state
# 0               NaN
# 1                OR
# 2                CA
# 3                CA
# 4                CA
#
# [5 rows x 29 columns]

# %%
fw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11241 entries, 0 to 11240
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tail_number               11241 non-null  object
#  1   date                      11241 non-null  object
#  2   aircraft                  11215 non-null  object
#  3   origin                    11241 non-null  object
#  4   origin_location           11241 non-null  object
#  5   destination               11239 non-null  object
#  6   destination_location      11239 non-null  object
#  7   departure                 11241 non-null  object
#  8   arrival                   11012 non-null  object
#  9   duration                  11009 non-null  object
#  10  medical_service           11241 non-null  object
#  11  origin_Latitude           10344 non-null  float64
#  12  origin_Longitude          10344 non-null  float64
#  13  destination_Latitude      10346 non-null  float64
#  14  destination_Longitude     10346 non-null  float64
#  15  ICAO_code_origin          11217 non-null  object
#  16  iata_code_origin          11161 non-null  object
#  17  AIRPORT_NAME_origin       11144 non-null  object
#  18  CITY_NAME_origin          11144 non-null  object
#  19  COUNTRY_NAME_origin       11144 non-null  object
#  20  STATE_NAME_origin         11096 non-null  object
#  21  origin_state              11213 non-null  object
#  22  ICAO_code_destination     11212 non-null  object
#  23  iata_code_destination     11162 non-null  object
#  24  AIRPORT_NAME_destination  11145 non-null  object
#  25  CITY_NAME_destination     11145 non-null  object
#  26  COUNTRY_NAME_destination  11145 non-null  object
#  27  STATE_NAME_destination    11096 non-null  object
#  28  destination_state         11212 non-null  object
# dtypes: float64(4), object(25)
# memory usage: 2.5+ MB

# %%
# Check count of duplicate values for fixed wing dataset
fw_df.duplicated().sum()
# Out:
# 0

# %%
# Check count of null values for the fixed wing dataset
fw_df.isna().sum()
# Out:
# tail_number                   0
# date                          0
# aircraft                     26
# origin                        0
# origin_location               0
# destination                   2
# destination_location          2
# departure                     0
# arrival                     229
# duration                    232
# medical_service               0
# origin_Latitude             897
# origin_Longitude            897
# destination_Latitude        895
# destination_Longitude       895
# ICAO_code_origin             24
# iata_code_origin             80
# AIRPORT_NAME_origin          97
# CITY_NAME_origin             97
# COUNTRY_NAME_origin          97
# STATE_NAME_origin           145
# origin_state                 28
# ICAO_code_destination        29
# iata_code_destination        79
# AIRPORT_NAME_destination     96
# CITY_NAME_destination        96
# COUNTRY_NAME_destination     96
# STATE_NAME_destination      145
# destination_state            29
# dtype: int64

# %%
# Create a new dataframe with attributes tail_number, ICAO_code_origin, ICAO_code_destination
new_df = fw_df[['tail_number','ICAO_code_origin', 'ICAO_code_destination']]

# %%
# Check count of null values
new_df.isna().sum()
# Out:
# tail_number               0
# ICAO_code_origin         24
# ICAO_code_destination    29
# dtype: int64

# %%
# Drop null values
new_df = new_df.dropna()

# %%
# Concat values and store in a new column Path
new_df['Path'] = new_df['ICAO_code_origin'] + new_df['ICAO_code_destination']

# %%
new_df
# Out:
#       tail_number ICAO_code_origin ICAO_code_destination      Path
# 2          N7025P             KSMF                  KRDD  KSMFKRDD
# 3          N7025P             KRBL                  KSMF  KRBLKSMF
# 5          N269GJ             KARR                  KFXE  KARRKFXE
# 6          N888CP             KPIA                  KARR  KPIAKARR
# 7          N888CP             KMDW                  KPIA  KMDWKPIA
# ...           ...              ...                   ...       ...
# 11236      N977TC             KELP                  KHOU  KELPKHOU
# 11237      N977TC             KHOU                  KELP  KHOUKELP
# 11238      N102WK             KMQY                  KSHV  KMQYKSHV
# 11239      N102WK             KSHV                  KMQY  KSHVKMQY
# 11240      N102WK             KSHV                  KSHV  KSHVKSHV
#
# [11193 rows x 4 columns]

# %%
# Get total count of each Path 
res = pd.DataFrame(new_df.Path.value_counts().sort_values(ascending=True)).rename(columns={"Path":"PathFreq"}).reset_index()
res
# Out:
#                index  PathFreq
# 0           KMYFKBIH         1
# 1           KUNUKVNC         1
# 2           KHIOKACV         1
# 3           KFATKBIH         1
# 4           KSLNKDDC         1
# ...              ...       ...
# 3604  PHNLOGG / PHOG        72
# 3605        KAPAKGJT        84
# 3606        KABQKFMN        93
# 3607        KFMNKABQ        97
# 3608        KBILKGGW       125
#
# [3609 rows x 2 columns]

# %%
# Check if duplicates
res.duplicated().sum()
# Out:
# 0

# %%
# Join 'res' dataframe with 'new_df' dataframe based on Path and index
new_df2 = new_df.merge(res, how='left', left_on='Path', right_on='index')
new_df2
# Out:
#       tail_number ICAO_code_origin ICAO_code_destination      Path     index  \
# 0          N7025P             KSMF                  KRDD  KSMFKRDD  KSMFKRDD
# 1          N7025P             KRBL                  KSMF  KRBLKSMF  KRBLKSMF
# 2          N269GJ             KARR                  KFXE  KARRKFXE  KARRKFXE
# 3          N888CP             KPIA                  KARR  KPIAKARR  KPIAKARR
# 4          N888CP             KMDW                  KPIA  KMDWKPIA  KMDWKPIA
# ...           ...              ...                   ...       ...       ...
# 11188      N977TC             KELP                  KHOU  KELPKHOU  KELPKHOU
# 11189      N977TC             KHOU                  KELP  KHOUKELP  KHOUKELP
# 11190      N102WK             KMQY                  KSHV  KMQYKSHV  KMQYKSHV
# 11191      N102WK             KSHV                  KMQY  KSHVKMQY  KSHVKMQY
# 11192      N102WK             KSHV                  KSHV  KSHVKSHV  KSHVKSHV
#
#        PathFreq
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 11188         9
# 11189         8
# 11190         1
# 11191         1
# 11192         1
#
# [11193 rows x 6 columns]

# %%
# Store dataframe in a csv file
new_df2.to_csv('D:/GMU/1 Spring-2021/DAEN-690/Project/Dataset/FW_anomaly.csv')
