# %%
#load packages
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

# %%
#load data and convert dates to datetime
fw = pd.read_csv("../Datasets/FW/FW_with_airports.csv")
fw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11241 entries, 0 to 11240
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tail_number               11240 non-null  object
#  1   date                      11240 non-null  object
#  2   aircraft                  11214 non-null  object
#  3   origin                    11240 non-null  object
#  4   origin_location           11240 non-null  object
#  5   destination               11238 non-null  object
#  6   destination_location      11238 non-null  object
#  7   departure                 11240 non-null  object
#  8   arrival                   11011 non-null  object
#  9   duration                  11008 non-null  object
#  10  medical_service           11240 non-null  object
#  11  origin_Latitude           11240 non-null  float64
#  12  origin_Longitude          11240 non-null  float64
#  13  destination_Latitude      11240 non-null  float64
#  14  destination_Longitude     11240 non-null  float64
#  15  ICAO_code_origin          11235 non-null  object
#  16  ICAO_code_destination     11226 non-null  object
#  17  iata_code_origin          11240 non-null  object
#  18  iata_code_destination     11240 non-null  object
#  19  AIRPORT_NAME_origin       11240 non-null  object
#  20  CITY_NAME_origin          11240 non-null  object
#  21  COUNTRY_NAME_origin       11240 non-null  object
#  22  STATE_NAME_origin         11086 non-null  object
#  23  STATE_CODE_origin         11086 non-null  object
#  24  AIRPORT_NAME_destination  11238 non-null  object
#  25  CITY_NAME_destination     11238 non-null  object
#  26  COUNTRY_NAME_destination  11238 non-null  object
#  27  STATE_NAME_destination    11077 non-null  object
#  28  STATE_CODE_destination    11077 non-null  object
# dtypes: float64(4), object(25)
# memory usage: 2.5+ MB

# %%
ICAO_origin = set(fw.ICAO_code_origin.dropna())
len(ICAO_origin)
# Out:
# 938

# %%
url = 'http://www.ogimet.com/display_stations.php?lang=en&tipo=AND&isyn=&oaci=&nombre=&estado=&Send=Send'

# %%
# BeautifulSoup Magic
uClient = uReq(url)
page_html = uClient.read()
uClient.close()

# %%
page_soup = soup(page_html, 'html.parser')
codes = page_soup.findAll("a", {"onmouseout":" return nd();"})

# %%
ICAO = []

for i in range(len(codes)):
    ICAO += codes[i]

# %%
origin_ICAO = []

for i in range(len(codes)):
    if ICAO[i] in ICAO_origin:
        origin_ICAO += [ICAO[i]]

# %%
url_2 = "http://www.ogimet.com/display_metars2.php?lang=en&lugar="
months = ['&tipo=ALL&ord=REV&nil=SI&fmt=html&ano=2021&mes=02&day=01&hora=23&anof=2021&mesf=02&dayf=28&horaf=23&minf=59&send=send', 
          '&tipo=ALL&ord=REV&nil=SI&fmt=html&ano=2021&mes=01&day=01&hora=23&anof=2021&mesf=01&dayf=31&horaf=23&minf=59&send=send',
         '&tipo=ALL&ord=REV&nil=SI&fmt=html&ano=2020&mes=12&day=01&hora=23&anof=2020&mesf=12&dayf=31&horaf=23&minf=59&send=send',
         '&tipo=ALL&ord=REV&nil=SI&fmt=html&ano=2020&mes=11&day=01&hora=23&anof=2020&mesf=11&dayf=30&horaf=23&minf=59&send=send']
date = []
METAR = []
ICAO_origin = []

for x in origin_ICAO:
    for j in months:
        url = url_2 + x + j
        uClient = uReq(url)
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, 'html.parser')
    
        for i in range(len(page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']}))):
            ICAO_origin += [x]
            date += page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']})[i].findAll('td')[1]
            METAR += [page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']})[i].findAll('td')[2].text]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-eb317f5215ad> in <module>
#      18         for i in range(len(page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']}))):
#      19             ICAO_origin += [x]
# ---> 20             date += page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']})[i].findAll('td')[1]
#      21             METAR += [page_soup.findAll("tr", {"bgcolor":["#F0F0D0",'white']})[i].findAll('td')[2].text]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1786         if not recursive:
#    1787             generator = self.children
# -> 1788         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1789     findAll = find_all       # BS3
#    1790     findChildren = find_all  # BS2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     781                 break
#     782             if i:
# --> 783                 found = strainer.search(i)
#     784                 if found:
#     785                     results.append(found)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in search(self, markup)
#    2063         elif isinstance(markup, Tag):
#    2064             if not self.text or self.name or self.attrs:
# -> 2065                 found = self.search_tag(markup)
#    2066         # If it's text, make sure the text matches.
#    2067         elif isinstance(markup, NavigableString) or \
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1997             markup_attrs = markup
#    1998
# -> 1999         if isinstance(self.name, str):
#    2000             # Optimization for a very common case where the user is
#    2001             # searching for a tag with one specific name, and we're
#
# KeyboardInterrupt:

# %%
METAR
# Out:
# ['METAR KAAO 282354Z AUTO 35015KT 10SM CLR 08/M03 A3007 RMK\n           AO2 SLP190 T00831028 10122 20083 53017 $=',
#  'METAR KAAO 282254Z AUTO 33016KT 10SM CLR 11/M03 A3004 RMK\n           AO2 SLP177 T01061033 $=',
#  'METAR KAAO 282154Z AUTO 35018G25KT 10SM CLR 12/M03 A3003\n           RMK AO2 PK WND 35027/2103 SLP172 T01171033 $=',
#  'METAR KAAO 282054Z AUTO 35016G24KT 10SM CLR 12/M02 A3002\n           RMK AO2 SLP168 T01171017 56007 $=',
#  'METAR KAAO 281954Z AUTO 34017G25KT 10SM CLR 12/M01 A3002\n           RMK AO2 PK WND 33028/1858 SLP168 T01221011 $=',
#  'METAR KAAO 281854Z AUTO 35019G26KT 10SM CLR 11/M01 A3004\n           RMK AO2 PK WND 33029/1755 SLP171 T01111011 $=',
#  'METAR KAAO 281754Z AUTO 34018G26KT 10SM CLR 10/M01 A3004\n           RMK AO2 PK WND 35028/1719 SLP173 T01001006 10100\n           20022 51021 $=',
#  'METAR KAAO 281654Z AUTO 33015G26KT 10SM CLR 09/00 A3003 RMK\n           AO2 PK WND 34026/1646 SLP169 T00890000 $=',
#  'METAR KAAO 281554Z AUTO 34018KT 10SM CLR 06/M01 A3000 RMK\n           AO2 SLP162 T00611006 $=',
#  'METAR KAAO 281454Z AUTO 32012KT 10SM CLR 03/M01 A2998 RMK\n           AO2 SLP155 T00281011 53028 $=',
#  'METAR KAAO 281354Z AUTO 33012KT 10SM CLR 02/M01 A2993 RMK\n           AO2 SLP139 T00221011 $=',
#  'METAR KAAO 281254Z AUTO 33012KT 10SM CLR 02/M01 A2990 RMK\n           AO2 SLP130 T00221006 $=',
#  'METAR KAAO 281154Z AUTO 34009KT 10SM CLR 02/00 A2989 RMK\n           AO2 SLP125 70001 T00220000 10128 20022 53026=',
#  'METAR KAAO 281054Z AUTO 34012KT 10SM CLR 04/01 A2984 RMK\n           AO2 SLP108 T00390011=',
#  'METAR KAAO 280954Z AUTO 34011KT 10SM CLR 04/02 A2981 RMK\n           AO2 SLP097 T00440017=',
#  'METAR KAAO 280854Z AUTO 34014KT 10SM CLR 07/03 A2981 RMK\n           AO2 SLP093 T00670028 51017=',
#  'SPECI KAAO 280805Z AUTO 32013G22KT 10SM FEW021 SCT026 08/03\n           A2980 RMK AO2 T00780033=',
#  'METAR KAAO 280754Z AUTO 32017G25KT 10SM FEW009 SCT013 BKN029\n           08/04 A2980 RMK AO2 PK WND 31026/0730 WSHFT 0729\n           SLP090 T00830039=',
#  'SPECI KAAO 280749Z AUTO 32016KT 10SM FEW009 SCT012 OVC026\n           09/04 A2980 RMK AO2 PK WND 31026/0730 WSHFT 0729=',
#  'SPECI KAAO 280720Z AUTO 26007KT 8SM SCT007 BKN013 OVC025\n           12/11 A2978 RMK AO2 T01220111=',
#  'SPECI KAAO 280711Z AUTO 27007KT 8SM BKN005 OVC017 12/11 A2977\n           RMK AO2 CIG 004V009 T01220111=',
#  'METAR KAAO 280654Z AUTO 25008KT 8SM OVC004 13/12 A2976 RMK\n           AO2 SLP074 T01280117=',
#  'SPECI KAAO 280646Z AUTO 24006KT 8SM OVC004 13/12 A2975 RMK\n           AO2 T01280117=',
#  'SPECI KAAO 280601Z AUTO 21009KT 8SM BKN005 OVC015 13/12 A2974\n           RMK AO2 T01280117=',
#  'METAR KAAO 280554Z AUTO 21009KT 6SM BR BKN004 BKN016 OVC021\n           13/12 A2974 RMK AO2 RAB08E26 SLP067 P0001 60001\n           T01280117 10156 20122 401830028 53009=',
#  'SPECI KAAO 280541Z AUTO 19010KT 3SM BR BKN004 BKN021 OVC047\n           12/12 A2973 RMK AO2 RAB08E26 P0001 T01220117=',
#  'SPECI KAAO 280530Z AUTO 18010KT 3SM BR BKN005 OVC021 13/12\n           A2973 RMK AO2 RAB08E26 P0001 T01280117=',
#  'SPECI KAAO 280519Z AUTO 21010KT 2 1/2SM -RA BR OVC005 13/12\n           A2974 RMK AO2 RAB08 P0001 T01280117=',
#  'METAR KAAO 280454Z AUTO 18011G20KT 9SM OVC006 13/11 A2972\n           RMK AO2 SLP064 T01280111=',
#  'METAR KAAO 280354Z AUTO 18014KT 9SM OVC009 13/10 A2971 RMK\n           AO2 CIG 008V011 SLP062 T01280100=',
#  'SPECI KAAO 280351Z AUTO 18015KT 10SM OVC009 13/10 A2971 RMK\n           AO2 CIG 008V013=',
#  'METAR KAAO 280254Z AUTO 17015G24KT 10SM OVC011 13/10 A2970\n           RMK AO2 PK WND 16028/0158 SLP059 T01280100 50007=',
#  'SPECI KAAO 280215Z AUTO 17015KT 10SM OVC012 13/10 A2970 RMK\n           AO2 PK WND 16028/0158 T01280100=',
#  'METAR KAAO 280154Z AUTO 17017G25KT 10SM OVC015 13/09 A2970\n           RMK AO2 PK WND 18030/0123 SLP060 T01330094=',
#  'METAR KAAO 280054Z AUTO 17019G28KT 10SM OVC020 14/09 A2969\n           RMK AO2 PK WND 17028/0016 SLP057 T01440089=',
#  'METAR KAAO 272354Z AUTO 16019G26KT 10SM OVC026 16/07 A2968\n           RMK AO2 PK WND 17026/2354 SLP051 T01560067 10183\n           20144 56010=',
#  'METAR KAAO 272254Z AUTO 17016G22KT 10SM OVC025 16/06 A2970\n           RMK AO2 PK WND 17031/2155 SLP057 T01560061=',
#  'SPECI KAAO 272216Z AUTO 17019G28KT 10SM OVC029 16/07 A2969\n           RMK AO2 PK WND 17031/2155 T01610067=',
#  'METAR KAAO 272154Z AUTO 17020G34KT 10SM BKN031 17/07 A2969\n           RMK AO2 PK WND 17034/2151 SLP055 T01720067=',
#  'METAR KAAO 272054Z AUTO 17019G29KT 10SM FEW031 18/08 A2971\n           RMK AO2 PK WND 16031/2037 SLP061 T01780078 56037=',
#  'SPECI KAAO 272024Z AUTO 16015KT 10SM OVC031 17/07 A2972 RMK\n           AO2 PK WND 16028/1956 T01720072=',
#  'SPECI KAAO 272002Z AUTO 15018G28KT 10SM BKN027 17/07 A2973\n           RMK AO2 PK WND 16028/1956 T01670072=',
#  'METAR KAAO 271954Z AUTO 16017G29KT 10SM SCT027 17/07 A2974\n           RMK AO2 PK WND 16035/1912 SLP070 T01670072=',
#  'METAR KAAO 271854Z AUTO 17019G31KT 10SM CLR 16/07 A2978 RMK\n           AO2 PK WND 16034/1833 SLP086 T01610072=',
#  'METAR KAAO 271754Z AUTO 16019G30KT 10SM FEW021 14/07 A2982\n           RMK AO2 PK WND 15031/1734 SLP102 T01440072 10144\n           20039 58016=',
#  'SPECI KAAO 271721Z AUTO 16020G26KT 10SM SCT009 12/07 A2984\n           RMK AO2 PK WND 15026/1721 T01220072=',
#  'METAR KAAO 271654Z AUTO 15015G23KT 10SM OVC004 08/07 A2985\n           RMK AO2 CIG 003V008 SLP114 T00830072=',
#  'SPECI KAAO 271649Z AUTO 15016G24KT 9SM OVC004 08/07 A2985\n           RMK AO2 CIG 003V008=',
#  'METAR KAAO 271554Z AUTO 14015G25KT 3SM BR OVC002 06/06 A2987\n           RMK AO2 SLP123 T00610056=',
#  'SPECI KAAO 271552Z AUTO 15015G25KT 2 1/2SM BR OVC002 06/06\n           A2987 RMK AO2=',
#  'SPECI KAAO 271540Z AUTO 14014KT 1 1/4SM BR OVC002 06/06 A2988\n           RMK AO2 T00610056=',
#  'SPECI KAAO 271514Z AUTO 14012KT 1/2SM FG VV002 05/04 A2989\n           RMK AO2 T00500044=',
#  'METAR KAAO 271454Z AUTO 14011KT 1/4SM FG VV002 05/04 A2990\n           RMK AO2 SLP131 T00500039 53001=',
#  'SPECI KAAO 271419Z AUTO 14009KT 1/4SM FG VV002 04/04 A2988\n           RMK AO2 T00440039=',
#  'METAR KAAO 271354Z AUTO 11008KT M1/4SM FG VV002 04/04 A2988\n           RMK AO2 SLP126 T00440039=',
#  'SPECI KAAO 271325Z AUTO 13008KT M1/4SM FG VV002 04/04 A2988\n           RMK AO2 T00440039=',
#  'METAR KAAO 271254Z AUTO 12008KT 1/4SM FG VV002 04/04 A2989\n           RMK AO2 SLP128 T00440039=',
#  'METAR KAAO 271154Z AUTO 17007KT 1/4SM FG VV002 04/04 A2989\n           RMK AO2 SLP128 T00390039 10044 20028 53006=',
#  'METAR KAAO 271054Z AUTO 18009KT 1/4SM FG VV002 04/04 A2988\n           RMK AO2 SLP124 T00390039=',
#  'METAR KAAO 270954Z AUTO 16011KT 1/4SM FG VV002 04/03 A2987\n           RMK AO2 SLP120 T00390033=',
#  'SPECI KAAO 270917Z AUTO 16011KT 1/4SM FG VV002 04/04 A2987\n           RMK AO2 T00440039=',
#  'METAR KAAO 270854Z AUTO 16010KT 3/4SM BR VV002 04/03 A2987\n           RMK AO2 SLP120 T00440033 58005=',
#  'SPECI KAAO 270843Z AUTO 15011KT 1 3/4SM BR OVC002 04/03 A2988\n           RMK AO2 T00440033=',
#  'SPECI KAAO 270814Z AUTO 16008KT 4SM BR OVC003 04/03 A2989\n           RMK AO2 T00440033=',
#  'METAR KAAO 270754Z AUTO 17008KT 5SM BR OVC004 04/03 A2990\n           RMK AO2 SLP130 T00390028=',
#  'SPECI KAAO 270742Z AUTO 16008KT 5SM BR BKN004 03/02 A2988\n           RMK AO2 T00330022=',
#  'SPECI KAAO 270727Z AUTO 15009KT 5SM BR FEW004 03/02 A2987\n           RMK AO2 T00330017=',
#  'METAR KAAO 270654Z AUTO 14008KT 7SM CLR 03/02 A2987 RMK AO2\n           SLP119 T00330022=',
#  'METAR KAAO 270554Z AUTO 15008KT 9SM CLR 03/01 A2989 RMK AO2\n           SLP127 T00280011 10078 20028 401111050 50012=',
#  'METAR KAAO 270454Z AUTO 15006KT 10SM CLR 03/01 A2990 RMK\n           AO2 SLP130 T00280011=',
#  'METAR KAAO 270354Z AUTO 15007KT 10SM CLR 03/01 A2989 RMK\n           AO2 SLP129 T00280006=',
#  'METAR KAAO 270254Z AUTO 13003KT 10SM CLR 04/01 A2985 RMK\n           AO2 SLP118 T00390011 53013=',
#  'METAR KAAO 270154Z AUTO 13004KT 10SM CLR 04/01 A2984 RMK\n           AO2 SLP116 T00440011=',
#  'METAR KAAO 270054Z AUTO 13004KT 10SM CLR 06/02 A2982 RMK\n           AO2 SLP108 T00610017=',
#  'METAR KAAO 262354Z AUTO 18006KT 10SM CLR 08/02 A2981 RMK\n           AO2 SLP106 T00780017 10111 20078 51008=',
#  'METAR KAAO 262254Z AUTO 22010KT 10SM SCT028 10/02 A2981 RMK\n           AO2 SLP104 T01000022=',
#  'METAR KAAO 262154Z AUTO 19009KT 10SM CLR 11/02 A2979 RMK\n           AO2 SLP097 T01060022=',
#  'METAR KAAO 262054Z AUTO 18013KT 10SM CLR 11/02 A2979 RMK\n           AO2 SLP095 T01060022 56028=',
#  'METAR KAAO 261954Z AUTO 17010KT 10SM FEW028 BKN060 09/02\n           A2983 RMK AO2 SLP109 T00890017=',
#  'SPECI KAAO 261929Z AUTO 20010KT 10SM BKN028 09/01 A2985 RMK\n           AO2 T00940011=',
#  'SPECI KAAO 261914Z AUTO 20011KT 10SM FEW024 SCT030 10/01\n           A2985 RMK AO2 T01000011=',
#  'METAR KAAO 261854Z AUTO 17010KT 10SM OVC024 11/02 A2988 RMK\n           AO2 PRESFR SLP124 T01060017 PWINO $=',
#  'METAR KAAO 261754Z AUTO 20012KT 10SM BKN024 09/01 A2992 RMK\n           AO2 SLP141 T00890006 10100 21039 56018 PWINO $=',
#  'METAR KAAO 261654Z AUTO 20013KT 10SM CLR 09/00 A2995 RMK\n           AO2 SLP148 T00890000 PWINO $=',
#  'METAR KAAO 261554Z AUTO 16008KT 10SM CLR 06/M02 A2995 RMK\n           AO2 SLP151 T00561022=',
#  'METAR KAAO 261454Z AUTO 15006KT 10SM FEW049 01/M03 A2998\n           RMK AO2 SLP164 T00111033 56008=',
#  'METAR KAAO 261354Z AUTO 00000KT 10SM SCT050 M03/M07 A2999\n           RMK AO2 SLP169 T10331067=',
#  'METAR KAAO 261254Z AUTO 12003KT 10SM CLR M03/M07 A2999 RMK\n           AO2 SLP169 T10331072=',
#  'METAR KAAO 261154Z AUTO 13003KT 10SM CLR M03/M07 A3000 RMK\n           AO2 SLP172 T10331072 10000 21050 56013=',
#  'METAR KAAO 261054Z AUTO 07003KT 10SM CLR M04/M07 A3002 RMK\n           AO2 SLP176 T10391072=',
#  'METAR KAAO 260954Z AUTO 04004KT 10SM CLR M03/M07 A3002 RMK\n           AO2 SLP176 T10281067=',
#  'METAR KAAO 260854Z AUTO 05005KT 10SM CLR M03/M07 A3004 RMK\n           AO2 SLP185 T10281067 58032=',
#  'METAR KAAO 260754Z AUTO 04005KT 10SM CLR M02/M07 A3009 RMK\n           AO2 SLP202 T10221067=',
#  'METAR KAAO 260654Z AUTO 04003KT 10SM SCT095 M01/M06 A3012\n           RMK AO2 SLP209 T10061061=',
#  'METAR KAAO 260554Z AUTO 05004KT 10SM BKN095 M01/M06 A3014\n           RMK AO2 SLP219 T10061056 10056 21006 400721022\n           58016=',
#  'METAR KAAO 260454Z AUTO 05005KT 10SM OVC100 01/M05 A3016\n           RMK AO2 SLP225 T00111050=',
#  'METAR KAAO 260354Z AUTO 06006KT 10SM BKN100 01/M06 A3018\n           RMK AO2 SLP234 T00061061=',
#  'METAR KAAO 260254Z AUTO 07004KT 10SM CLR 01/M06 A3019 RMK\n           AO2 SLP237 T00061061 58012=',
#  'METAR KAAO 260154Z AUTO 05004KT 10SM SCT100 02/M06 A3021\n           RMK AO2 SLP245 T00171061=',
#  'METAR KAAO 260054Z AUTO 06006KT 10SM FEW100 03/M06 A3022\n           RMK AO2 SLP246 T00281061=',
#  'METAR KAAO 252354Z AUTO 05009KT 10SM OVC110 06/M06 A3023\n           RMK AO2 SLP248 T00561061 10072 20050 56030=',
#  'METAR KAAO 252254Z AUTO 06010KT 10SM OVC110 07/M06 A3026\n           RMK AO2 SLP258 T00671061=',
#  'METAR KAAO 252154Z AUTO 06011KT 10SM OVC120 07/M06 A3029\n           RMK AO2 SLP267 T00721061=',
#  'METAR KAAO 252054Z AUTO 03008KT 10SM OVC110 07/M05 A3032\n           RMK AO2 SLP280 T00671050 56030=',
#  'METAR KAAO 251954Z AUTO 03007KT 10SM OVC110 06/M04 A3035\n           RMK AO2 SLP289 T00611044=',
#  'METAR KAAO 251854Z AUTO 03004KT 10SM OVC110 06/M04 A3038\n           RMK AO2 SLP302 T00561039=',
#  'METAR KAAO 251754Z AUTO 04006KT 10SM OVC110 05/M03 A3041\n           RMK AO2 SLP312 T00501033 10056 21022 51002=',
#  'METAR KAAO 251654Z AUTO 36004KT 10SM OVC110 04/M03 A3041\n           RMK AO2 SLP310 T00391028=',
#  'METAR KAAO 251554Z AUTO 08003KT 10SM OVC110 02/M03 A3042\n           RMK AO2 SLP317 T00171028=',
#  'METAR KAAO 251454Z AUTO 07005KT 10SM OVC110 01/M03 A3041\n           RMK AO2 SLP310 T00061028 53019=',
#  'METAR KAAO 251354Z AUTO 02005KT 10SM CLR M01/M04 A3039 RMK\n           AO2 SLP305 T10111039=',
#  'METAR KAAO 251254Z AUTO 08003KT 10SM FEW100 M02/M04 A3037\n           RMK AO2 SLP297 T10221044=',
#  'METAR KAAO 251154Z AUTO 03007KT 10SM BKN120 M01/M04 A3035\n           RMK AO2 SLP287 T10111039 11011 21022 58002=',
#  'METAR KAAO 251054Z AUTO 04005KT 10SM SCT120 M01/M04 A3035\n           RMK AO2 SLP288 T10111039=',
#  'METAR KAAO 250954Z AUTO 03006KT 10SM BKN120 M01/M04 A3035\n           RMK AO2 SLP287 T10111039=',
#  'METAR KAAO 250854Z AUTO 03005KT 10SM CLR M02/M04 A3036 RMK\n           AO2 SLP289 T10221044 56000=',
#  'METAR KAAO 250754Z AUTO 04004KT 10SM CLR M02/M04 A3036 RMK\n           AO2 SLP289 T10171044=',
#  'METAR KAAO 250654Z AUTO 03007KT 10SM SCT110 M02/M04 A3035\n           RMK AO2 SLP288 T10171044=',
#  'METAR KAAO 250554Z AUTO 01006KT 10SM CLR M01/M04 A3036 RMK\n           AO2 SLP290 T10111044 10078 21017 401111017 51020=',
#  'METAR KAAO 250454Z AUTO 02004KT 10SM CLR M01/M04 A3036 RMK\n           AO2 SLP290 T10111044=',
#  'METAR KAAO 250354Z AUTO 36007KT 10SM CLR M01/M05 A3034 RMK\n           AO2 SLP286 T10111050=',
#  'METAR KAAO 250254Z AUTO 01008KT 10SM CLR 01/M04 A3030 RMK\n           AO2 SLP271 T00111044 51028=',
#  'METAR KAAO 250154Z AUTO 01006KT 10SM CLR 02/M06 A3027 RMK\n           AO2 SLP263 T00221056=',
#  'METAR KAAO 250054Z AUTO 01006KT 10SM SCT120 03/M06 A3024\n           RMK AO2 SLP253 T00331061=',
#  'METAR KAAO 242354Z AUTO 36011KT 10SM FEW120 08/M06 A3021\n           RMK AO2 SLP238 T00781056 10111 20078 53009=',
#  'METAR KAAO 242254Z AUTO 36012KT 10SM CLR 10/M07 A3019 RMK\n           AO2 SLP232 T01001067=',
#  'METAR KAAO 242154Z AUTO 36015KT 10SM OVC120 11/M06 A3018\n           RMK AO2 SLP225 T01111061=',
#  'METAR KAAO 242054Z AUTO 34016G22KT 10SM SCT120 11/M05 A3018\n           RMK AO2 SLP223 T01111050 53001=',
#  'METAR KAAO 241954Z AUTO 34012G28KT 10SM CLR 11/M04 A3017\n           RMK AO2 PK WND 35028/1950 SLP220 T01061044=',
#  'METAR KAAO 241854Z AUTO 33016G21KT 10SM CLR 09/M03 A3018\n           RMK AO2 SLP224 T00941033=',
#  'METAR KAAO 241754Z AUTO 34013G23KT 10SM CLR 09/M03 A3018\n           RMK AO2 SLP224 T00891033 10089 20000 51021=',
#  'METAR KAAO 241654Z AUTO 34016KT 10SM CLR 07/M03 A3016 RMK\n           AO2 PK WND 36026/1558 SLP220 T00721028=',
#  'METAR KAAO 241554Z AUTO 35019G26KT 10SM CLR 06/M03 A3014\n           RMK AO2 PK WND 36030/1515 SLP211 T00561033=',
#  'METAR KAAO 241454Z AUTO 36019G25KT 10SM CLR 04/M03 A3011\n           RMK AO2 SLP202 T00441033 53043=',
#  'METAR KAAO 241354Z AUTO 35011KT 10SM CLR 02/M03 A3005 RMK\n           AO2 SLP183 T00221033=',
#  'METAR KAAO 241254Z AUTO 34008KT 10SM CLR 00/M04 A3002 RMK\n           AO2 SLP172 T00001044=',
#  'METAR KAAO 241154Z AUTO 36010KT 10SM CLR 02/M03 A2998 RMK\n           AO2 SLP155 T00221033 10100 20022 51040=',
#  'METAR KAAO 241054Z AUTO 36011KT 10SM CLR 03/M03 A2995 RMK\n           AO2 SLP142 T00281028=',
#  'METAR KAAO 240954Z AUTO 36015KT 10SM CLR 06/M02 A2990 RMK\n           AO2 PK WND 01033/0916 SLP123 T00561017=',
#  'METAR KAAO 240854Z AUTO 01019G30KT 10SM CLR 07/M02 A2986\n           RMK AO2 PK WND 01034/0800 SLP109 T00721017 53038=',
#  'METAR KAAO 240754Z AUTO 36026G34KT 10SM CLR 08/M01 A2982\n           RMK AO2 PK WND 01034/0753 SLP093 T00831006=',
#  'METAR KAAO 240654Z AUTO 36013KT 10SM CLR 08/00 A2975 RMK\n           AO2 SLP073 T00780000=',
#  'METAR KAAO 240554Z AUTO 34008KT 10SM CLR 08/01 A2974 RMK\n           AO2 SLP071 T00780006 10167 20039 402111011 53004=',
#  'METAR KAAO 240454Z AUTO 04003KT 10SM CLR 06/00 A2972 RMK\n           AO2 SLP067 T00610000=',
#  'METAR KAAO 240354Z AUTO 17004KT 10SM CLR 09/01 A2973 RMK\n           AO2 SLP068 T00890006=',
#  'METAR KAAO 240254Z AUTO 23004KT 10SM CLR 11/01 A2973 RMK\n           AO2 SLP070 T01060006 51014=',
#  'METAR KAAO 240154Z AUTO 00000KT 10SM CLR 12/01 A2973 RMK\n           AO2 SLP072 T01170006=',
#  'METAR KAAO 240054Z AUTO 20006KT 10SM CLR 13/00 A2971 RMK\n           AO2 SLP067 T01280000=',
#  'METAR KAAO 232354Z AUTO 18006KT 10SM CLR 17/00 A2969 RMK\n           AO2 SLP054 T01670000 10211 20167 56023=',
#  'METAR KAAO 232254Z AUTO 18014KT 10SM CLR 18/M02 A2970 RMK\n           AO2 SLP058 T01831017=',
#  'METAR KAAO 232154Z AUTO 16012G21KT 10SM CLR 20/M03 A2973\n           RMK AO2 SLP067 T02001033=',
#  'METAR KAAO 232054Z AUTO 20016KT 10SM CLR 21/M04 A2976 RMK\n           AO2 SLP075 T02061044 58037=',
#  'METAR KAAO 231954Z AUTO 20016KT 10SM CLR 20/M03 A2979 RMK\n           AO2 SLP087 T02001028=',
#  'METAR KAAO 231854Z AUTO 17012KT 10SM CLR 19/M03 A2984 RMK\n           AO2 SLP105 T01891028=',
#  'METAR KAAO 231754Z AUTO 16009KT 10SM CLR 17/M02 A2987 RMK\n           AO2 SLP115 T01671022 10167 21011 58028=',
#  'METAR KAAO 231654Z AUTO 15007KT 10SM CLR 13/M02 A2992 RMK\n           AO2 SLP134 T01281017=',
#  'METAR KAAO 231554Z AUTO 18008KT 10SM CLR 11/M03 A2996 RMK\n           AO2 SLP147 T01061028=',
#  'METAR KAAO 231454Z AUTO 26004KT 10SM CLR 07/M03 A2996 RMK\n           AO2 SLP149 T00671033 55007=',
#  'METAR KAAO 231354Z AUTO 00000KT 10SM CLR 01/M04 A2994 RMK\n           AO2 SLP144 T00111044=',
#  'METAR KAAO 231254Z AUTO 17004KT 10SM CLR M01/M06 A2997 RMK\n           AO2 SLP155 T10111061=',
#  'METAR KAAO 231154Z AUTO 30004KT 10SM CLR 02/M06 A2998 RMK\n           AO2 SLP157 T00171061 10072 20006 56005=',
#  'METAR KAAO 231054Z AUTO 28007KT 10SM CLR 03/M05 A2999 RMK\n           AO2 SLP157 T00331050=',
#  'METAR KAAO 230954Z AUTO 25006KT 10SM CLR 03/M05 A2998 RMK\n           AO2 SLP155 T00281050=',
#  'METAR KAAO 230854Z AUTO 27007KT 10SM CLR 05/M05 A3000 RMK\n           AO2 SLP161 T00501050 58005=',
#  'METAR KAAO 230754Z AUTO 27007KT 10SM CLR 06/M04 A3001 RMK\n           AO2 SLP166 T00561044=',
#  'METAR KAAO 230654Z AUTO 27008KT 10SM CLR 07/M03 A3002 RMK\n           AO2 SLP166 T00671028=',
#  'METAR KAAO 230554Z AUTO 22007KT 10SM CLR 06/M02 A3001 RMK\n           AO2 SLP166 T00611022 10139 20061 401611011 50005=',
#  'METAR KAAO 230454Z AUTO 23009KT 10SM CLR 08/M02 A3002 RMK\n           AO2 SLP166 T00831017=',
#  'METAR KAAO 230354Z AUTO 22009KT 10SM CLR 08/M01 A3000 RMK\n           AO2 SLP163 T00831011=',
#  'METAR KAAO 230254Z AUTO 22007KT 10SM CLR 09/M01 A3000 RMK\n           AO2 SLP163 T00891011 53008=',
#  'METAR KAAO 230154Z AUTO 22008KT 10SM CLR 10/M01 A2999 RMK\n           AO2 SLP163 T01001006=',
#  'METAR KAAO 230054Z AUTO 21009KT 10SM CLR 12/M01 A2998 RMK\n           AO2 SLP158 T01221011=',
#  'METAR KAAO 222354Z AUTO 21013KT 10SM CLR 14/M02 A2997 RMK\n           AO2 SLP156 T01441017 10161 20139 56011=',
#  'METAR KAAO 222254Z AUTO 20013KT 10SM CLR 16/M01 A2997 RMK\n           AO2 SLP155 T01561006=',
#  'METAR KAAO 222154Z AUTO 22014KT 10SM CLR 16/M02 A2999 RMK\n           AO2 SLP160 T01611017=',
#  'METAR KAAO 222054Z AUTO 21014G24KT 10SM CLR 15/M01 A3001\n           RMK AO2 SLP165 T01501011 56018=',
#  'METAR KAAO 221954Z AUTO 23014G21KT 10SM CLR 14/M02 A3002\n           RMK AO2 SLP172 T01441017=',
#  'METAR KAAO 221854Z AUTO 23013KT 10SM CLR 15/M02 A3003 RMK\n           AO2 SLP173 T01501022=',
#  'METAR KAAO 221754Z AUTO 23016G21KT 10SM CLR 14/M04 A3006\n           RMK AO2 SLP185 T01391039 10139 21011 57009=',
#  'METAR KAAO 221654Z AUTO 24016G21KT 10SM CLR 12/M05 A3007\n           RMK AO2 SLP188 T01171050=',
#  'METAR KAAO 221554Z AUTO 24014G21KT 10SM CLR 09/M07 A3008\n           RMK AO2 SLP194 T00891072=',
#  'METAR KAAO 221454Z AUTO 23011G19KT 10SM CLR 06/M07 A3009\n           RMK AO2 SLP198 T00561067 55000=',
#  'METAR KAAO 221354Z AUTO 26006KT 10SM CLR 01/M07 A3009 RMK\n           AO2 SLP199 T00111072=',
#  'METAR KAAO 221254Z AUTO 25006KT 10SM CLR M01/M08 A3008 RMK\n           AO2 SLP198 T10061078=',
#  'METAR KAAO 221154Z AUTO 26008KT 10SM CLR M01/M07 A3009 RMK\n           AO2 SLP199 T10111072 10011 21011 55003 $=',
#  'METAR KAAO 221054Z AUTO 26008KT 10SM CLR M01/M08 A3008 RMK\n           AO2 SLP193 T10111078 $=',
#  'METAR KAAO 220954Z AUTO 27008KT 10SM CLR M01/M07 A3009 RMK\n           AO2 SLP197 T10061072 $=',
#  'METAR KAAO 220854Z AUTO 25008KT 10SM CLR 00/M07 A3010 RMK\n           AO2 SLP200 T00001072 54000 $=',
#  'METAR KAAO 220754Z AUTO 27005KT 10SM CLR 00/M08 A3010 RMK\n           AO2 SLP202 T00001078 $=',
#  'METAR KAAO 220654Z AUTO 25006KT 10SM CLR 00/M07 A3010 RMK\n           AO2 SLP200 T00001072 $=',
#  'METAR KAAO 220554Z AUTO 25006KT 10SM CLR 01/M07 A3010 RMK\n           AO2 SLP201 T00061072 10083 20006 401060006 50003\n           $=',
#  'METAR KAAO 220454Z AUTO 26007KT 10SM CLR 02/M07 A3010 RMK\n           AO2 SLP204 T00171067 $=',
#  'METAR KAAO 220354Z AUTO 25006KT 10SM CLR 01/M07 A3010 RMK\n           AO2 SLP205 T00111067 $=',
#  'METAR KAAO 220254Z AUTO 26006KT 10SM CLR 03/M06 A3009 RMK\n           AO2 SLP198 T00281061 51026 $=',
#  'METAR KAAO 220154Z AUTO 29006KT 10SM CLR 03/M06 A3007 RMK\n           AO2 SLP194 T00331061 $=',
#  'METAR KAAO 220054Z AUTO 31008KT 10SM CLR 04/M06 A3005 RMK\n           AO2 SLP185 T00441056 $=',
#  'METAR KAAO 212354Z AUTO 32016G24KT 10SM CLR 08/M04 A3001\n           RMK AO2 SLP169 T00831044 10106 20078 53033 $=',
#  'METAR KAAO 212254Z AUTO 32013G24KT 10SM CLR 10/M02 A2997\n           RMK AO2 PK WND 33032/2156 SLP154 T01001022 $=',
#  'METAR KAAO 212154Z AUTO 33023G32KT 10SM CLR 10/M02 A2993\n           RMK AO2 PK WND 33032/2154 SLP142 T01001022 $=',
#  'METAR KAAO 212054Z AUTO 30015KT 10SM FEW036 09/00 A2991 RMK\n           AO2 PK WND 30026/2040 SLP133 T00940000 53005 $=',
#  'SPECI KAAO 212015Z AUTO 30013G21KT 10SM BKN031 09/01 A2989\n           RMK AO2 T00890006 $=',
#  'METAR KAAO 211954Z AUTO 31017G25KT 10SM OVC029 08/01 A2989\n           RMK AO2 SLP129 T00780006 $=',
#  'SPECI KAAO 211925Z AUTO 31015G22KT 10SM OVC029 08/01 A2990\n           RMK AO2 T00780006 $=',
#  'SPECI KAAO 211905Z AUTO 30014G22KT 10SM BKN030 08/01 A2989\n           RMK AO2 T00830006 $=',
#  'METAR KAAO 211854Z AUTO 31014G20KT 10SM BKN029 08/01 A2989\n           RMK AO2 SLP129 T00830006 $=',
#  'METAR KAAO 211754Z AUTO 30012KT 10SM CLR 08/01 A2989 RMK\n           AO2 SLP129 T00780006 10078 20011 53020 $=',
#  'SPECI KAAO 211735Z AUTO 30012G20KT 10SM FEW024 07/01 A2988\n           RMK AO2 T00720006 $=',
#  'METAR KAAO 211654Z AUTO 30014G21KT 10SM OVC023 05/00 A2987\n           RMK AO2 SLP123 T00500000 $=',
#  'METAR KAAO 211554Z AUTO 26008KT 10SM OVC024 03/M01 A2985\n           RMK AO2 SLP119 T00331006 $=',
#  'SPECI KAAO 211540Z AUTO 25008KT 10SM FEW011 OVC024 03/00\n           A2985 RMK AO2 T00280000 $=',
#  'SPECI KAAO 211517Z AUTO 26009KT 10SM BKN011 OVC023 03/01\n           A2984 RMK AO2 T00330006 $=',
#  'METAR KAAO 211454Z AUTO 22012KT 10SM OVC026 03/01 A2983 RMK\n           AO2 SLP110 T00330006 53015 $=',
#  'SPECI KAAO 211444Z AUTO 21012KT 10SM BKN026 OVC034 03/01\n           A2982 RMK AO2 T00330006 $=',
#  'METAR KAAO 211354Z AUTO 19012KT 10SM OVC037 03/00 A2979 RMK\n           AO2 SLP097 T00280000 $=',
#  'METAR KAAO 211254Z AUTO 18012KT 10SM SCT042 03/M01 A2978\n           RMK AO2 SLP092 T00281006 $=',
#  'METAR KAAO 211154Z AUTO 16008KT 10SM CLR 01/M02 A2978 RMK\n           AO2 SLP095 T00111017 10033 20011 50002 $=',
#  'METAR KAAO 211054Z AUTO 17009KT 10SM CLR 02/M02 A2979 RMK\n           AO2 SLP097 T00221017 $=',
#  'METAR KAAO 210954Z AUTO 16016G25KT 10SM CLR 03/M02 A2978\n           RMK AO2 PK WND 16031/0908 SLP090 T00331017 $=',
#  'METAR KAAO 210854Z AUTO 16020G30KT 10SM CLR 03/M02 A2978\n           RMK AO2 PK WND 16030/0847 SLP092 T00331017 58039\n           $=',
#  'METAR KAAO 210754Z AUTO 15019G28KT 10SM CLR 03/M02 A2982\n           RMK AO2 PK WND 17028/0752 SLP106 T00281022 $=',
#  'METAR KAAO 210654Z AUTO 15015G26KT 10SM CLR 03/M02 A2987\n           RMK AO2 PK WND 15027/0636 SLP122 T00281022 $=',
#  'METAR KAAO 210554Z AUTO 15015G22KT 10SM CLR 03/M03 A2990\n           RMK AO2 SLP134 T00281028 10044 20022 400611072\n           58010 $=',
#  'METAR KAAO 210454Z AUTO 15013KT 10SM CLR 03/M03 A2993 RMK\n           AO2 SLP147 T00281028 $=',
#  'METAR KAAO 210354Z AUTO 15009KT 10SM CLR 02/M02 A2994 RMK\n           AO2 SLP151 T00221022 $=',
#  'METAR KAAO 210254Z AUTO 15013KT 10SM CLR 03/M02 A2993 RMK\n           AO2 SLP148 T00281022 58014 $=',
#  'METAR KAAO 210154Z AUTO 15013KT 10SM CLR 03/M02 A2995 RMK\n           AO2 SLP157 T00281022 $=',
#  'METAR KAAO 210054Z AUTO 14012KT 10SM CLR 03/M02 A2996 RMK\n           AO2 SLP159 T00331022 $=',
#  'METAR KAAO 202354Z AUTO 14011KT 10SM CLR 04/M02 A2997 RMK\n           AO2 SLP165 T00441022 10061 20028 56024 $=',
#  'METAR KAAO 202254Z AUTO 15012G20KT 10SM CLR 06/M02 A3000\n           RMK AO2 SLP174 T00561022 $=',
#  'METAR KAAO 202154Z AUTO 17009KT 10SM CLR 06/M03 A3002 RMK\n           AO2 SLP178 T00611028 $=',
#  'METAR KAAO 202054Z AUTO 14010KT 10SM CLR 06/M03 A3005 RMK\n           AO2 SLP188 T00561028 58028 $=',
#  'METAR KAAO 201954Z AUTO 16011KT 10SM CLR 04/M04 A3008 RMK\n           AO2 SLP198 T00441039 $=',
#  'METAR KAAO 201854Z AUTO 18009KT 10SM CLR 04/M04 A3011 RMK\n           AO2 SLP210 T00391039 $=',
#  'METAR KAAO 201754Z AUTO 18011KT 10SM CLR 03/M04 A3013 RMK\n           AO2 SLP218 T00281044 10028 21072 58014 $=',
#  'METAR KAAO 201654Z AUTO 20010KT 10SM CLR 01/M06 A3017 RMK\n           AO2 SLP231 T00061056 $=',
#  'METAR KAAO 201554Z AUTO 20007KT 10SM CLR M01/M06 A3016 RMK\n           AO2 SLP229 T10061061 $=',
#  'METAR KAAO 201454Z AUTO 20007KT 10SM CLR M03/M07 A3017 RMK\n           AO2 SLP237 T10331072 55002 $=',
#  'METAR KAAO 201354Z AUTO 17005KT 8SM CLR M07/M09 A3017 RMK\n           AO2 SLP236 T10671094 $=',
#  'METAR KAAO 201254Z AUTO 19008KT 10SM CLR M07/M09 A3016 RMK\n           AO2 SLP234 T10721094 $=',
#  'METAR KAAO 201154Z AUTO 20007KT 10SM CLR M07/M09 A3018 RMK\n           AO2 SLP239 T10671094 11039 21072 58006 $=',
#  'METAR KAAO 201054Z AUTO 20008KT 10SM CLR M07/M09 A3019 RMK\n           AO2 SLP241 T10671094 $=',
#  'METAR KAAO 200954Z AUTO 20008KT 10SM CLR M06/M09 A3020 RMK\n           AO2 SLP245 T10611094 $=',
#  'METAR KAAO 200854Z AUTO 20010KT 10SM CLR M05/M09 A3020 RMK\n           AO2 SLP244 T10501089 56012 $=',
#  'METAR KAAO 200754Z AUTO 20009KT 10SM CLR M04/M08 A3021 RMK\n           AO2 SLP247 T10441083=',
#  'METAR KAAO 200654Z AUTO 20013G21KT 10SM CLR M04/M08 A3022\n           RMK AO2 SLP249 T10391083=',
#  'METAR KAAO 200554Z AUTO 21014KT 10SM CLR M04/M08 A3024 RMK\n           AO2 SLP257 T10391083 11017 21039 400061122 58003=',
#  'METAR KAAO 200454Z AUTO 21011KT 10SM CLR M03/M08 A3026 RMK\n           AO2 SLP266 T10331083=',
#  'METAR KAAO 200354Z AUTO 20011KT 10SM CLR M03/M08 A3026 RMK\n           AO2 SLP265 T10331078=',
#  'METAR KAAO 200254Z AUTO 19011KT 10SM CLR M03/M08 A3025 RMK\n           AO2 SLP264 T10331078 50004=',
#  'METAR KAAO 200154Z AUTO 19008KT 10SM CLR M03/M08 A3026 RMK\n           AO2 SLP268 T10331078=',
#  'METAR KAAO 200054Z AUTO 19011KT 10SM CLR M02/M07 A3024 RMK\n           AO2 SLP263 T10221072=',
#  'METAR KAAO 192354Z AUTO 18011KT 10SM CLR M02/M07 A3024 RMK\n           AO2 SLP261 T10171072 10006 21017 55004=',
#  'METAR KAAO 192254Z AUTO 18015G23KT 10SM CLR M01/M07 A3022\n           RMK AO2 SLP255 T10061067=',
#  'METAR KAAO 192154Z AUTO 19017G25KT 10SM CLR 00/M07 A3024\n           RMK AO2 SLP261 T00001067=',
#  'METAR KAAO 192054Z AUTO 19014KT 10SM CLR 00/M07 A3025 RMK\n           AO2 SLP263 T00001072 58031=',
#  'METAR KAAO 191954Z AUTO 19014KT 10SM CLR 00/M07 A3029 RMK\n           AO2 SLP277 T00001072=',
#  'METAR KAAO 191854Z AUTO 19016G20KT 10SM CLR M01/M07 A3032\n           RMK AO2 SLP287 T10061067=',
#  'METAR KAAO 191754Z AUTO 19011KT 10SM CLR M01/M08 A3034 RMK\n           AO2 SLP294 T10111078 11011 21117 58007=',
#  'METAR KAAO 191654Z AUTO 19010KT 10SM CLR M03/M08 A3037 RMK\n           AO2 SLP304 T10281083=',
#  'METAR KAAO 191554Z AUTO 21012KT 10SM CLR M04/M09 A3037 RMK\n           AO2 SLP304 T10441089 $=',
#  'METAR KAAO 191454Z AUTO 20008KT 7SM CLR M07/M10 A3037 RMK\n           AO2 SLP304 T10671100 55002 $=',
#  'METAR KAAO 190854Z AUTO 19003KT 7SM CLR M12/M14 A3039 RMK\n           AO2 SLP315 T11171139 58012=',
#  'METAR KAAO 190754Z AUTO 00000KT 8SM FEW095 M09/M12 A3041\n           RMK AO2 SLP319 T10891117=',
#  'METAR KAAO 190654Z AUTO 00000KT 7SM CLR M09/M12 A3041 RMK\n           AO2 SLP323 T10941122=',
#  'METAR KAAO 190554Z AUTO 00000KT 9SM CLR M07/M11 A3043 RMK\n           AO2 SLP325 T10671111 11044 21083 410221150 58010=',
#  'METAR KAAO 190454Z AUTO 00000KT 10SM FEW120 M07/M11 A3046\n           RMK AO2 SLP337 T10721111=',
#  'METAR KAAO 190354Z AUTO 00000KT 10SM OVC110 M07/M11 A3046\n           RMK AO2 SLP339 T10671111=',
#  'METAR KAAO 190254Z AUTO 00000KT 10SM OVC120 M05/M11 A3046\n           RMK AO2 SLP338 T10501111 53010=',
#  'METAR KAAO 190154Z AUTO 00000KT 10SM OVC120 M06/M11 A3044\n           RMK AO2 SLP337 T10561106=',
#  'METAR KAAO 190054Z AUTO 00000KT 10SM FEW120 M06/M11 A3044\n           RMK AO2 SLP334 T10561111=',
#  'METAR KAAO 182354Z AUTO 34005KT 10SM CLR M04/M11 A3042 RMK\n           AO2 SLP330 T10441106 11022 21056 51004=',
#  'METAR KAAO 182254Z AUTO 36008KT 10SM CLR M03/M10 A3042 RMK\n           AO2 SLP328 T10281100=',
#  'SPECI KAAO 182211Z AUTO 35009KT 10SM SCT030 M02/M09 A3042\n           RMK AO2 T10221094=',
#  'METAR KAAO 182154Z AUTO 36008KT 10SM BKN028 M02/M09 A3042\n           RMK AO2 SLP326 T10221094=',
#  'METAR KAAO 182054Z AUTO 34010KT 10SM OVC028 M04/M10 A3041\n           RMK AO2 SLP325 T10391100 58012=',
#  'METAR KAAO 181954Z AUTO 32007KT 10SM OVC027 M04/M11 A3042\n           RMK AO2 SLP328 T10441106=',
#  'SPECI KAAO 181931Z AUTO 10SM BKN025 M04/M11 A3044 RMK AO2\n           T10441111=',
#  'METAR KAAO 181854Z AUTO VRB03KT 10SM CLR M04/M11 A3045 RMK\n           AO2 SLP337 T10441111=',
#  'METAR KAAO 181754Z AUTO 35007KT 10SM CLR M06/M12 A3045 RMK\n           AO2 SLP337 I6000 T10561117 11056 21150 50003=',
#  'METAR KAAO 181654Z AUTO 04006KT 10SM FEW030 M07/M12 A3045\n           RMK AO2 SLP338 T10671117=',
#  'METAR KAAO 181554Z AUTO 35005KT 6SM HZ CLR M08/M12 A3045\n           RMK AO2 SLP337 T10831117=',
#  'METAR KAAO 181454Z AUTO 35006KT 6SM HZ CLR M11/M13 A3044\n           RMK AO2 SLP336 I3000 T11061133 53034=',
#  'METAR KAAO 181354Z AUTO 35005KT 6SM BR CLR M14/M16 A3039\n           RMK AO2 SLP321 T11391156=',
#  'METAR KAAO 181254Z AUTO 36006KT 9SM CLR M14/M17 A3036 RMK\n           AO2 SLP310 I1000 T11441167=',
#  'SPECI KAAO 181201Z AUTO 36006KT 10SM SCT028 M14/M17 A3034\n           RMK AO2 T11441167 $=',
#  'METAR KAAO 181154Z AUTO 35007KT 10SM BKN028 M14/M17 A3033\n           RMK AO2 SLP301 T11441167 11122 21150 53010 $=',
#  'SPECI KAAO 181128Z AUTO 01006KT 10SM BKN027 M14/M16 A3033\n           RMK AO2 T11391161 $=',
#  'METAR KAAO 181054Z AUTO 35006KT 10SM CLR M14/M17 A3031 RMK\n           AO2 SLP292 T11391167 $=',
#  'METAR KAAO 180954Z AUTO 35007KT SCT030 M14/M17 A3030 RMK\n           AO2 SLP286 T11391167 $=',
#  'METAR KAAO 180854Z AUTO 34004KT CLR M14/M17 A3030 RMK AO2\n           SLP287 T11391167 53005 $=',
#  'METAR KAAO 180754Z AUTO 32007KT 10SM CLR M13/M16 A3030 RMK\n           AO2 SLP286 T11281156=',
#  'METAR KAAO 180654Z AUTO 33005KT 10SM CLR M13/M16 A3029 RMK\n           AO2 SLP283 T11281156=',
#  'METAR KAAO 180554Z AUTO 31007KT 10SM CLR M13/M16 A3029 RMK\n           AO2 SLP283 T11281156 11083 21128 410611150 50003=',
#  'METAR KAAO 180454Z AUTO 32004KT 10SM CLR M12/M15 A3029 RMK\n           AO2 SLP283 T11171150=',
#  'METAR KAAO 180354Z AUTO 36004KT 10SM CLR M11/M15 A3028 RMK\n           AO2 SLP283 T11111150=',
#  'METAR KAAO 180254Z AUTO 00000KT 10SM CLR M11/M14 A3027 RMK\n           AO2 SLP281 T11061144 53037=',
#  'METAR KAAO 180154Z AUTO 00000KT 10SM CLR M11/M15 A3024 RMK\n           AO2 SLP271 T11111150=',
#  'METAR KAAO 180054Z AUTO 35005KT 10SM CLR M10/M14 A3019 RMK\n           AO2 SLP251 T11001144=',
#  'METAR KAAO 172354Z AUTO 02005KT 10SM CLR M08/M13 A3016 RMK\n           AO2 SLP241 T10831133 11061 21089 53011=',
#  'METAR KAAO 172254Z AUTO 03004KT 10SM CLR M07/M13 A3014 RMK\n           AO2 SLP234 T10671133=',
#  'METAR KAAO 172154Z AUTO 04005KT 10SM FEW024 M06/M13 A3013\n           RMK AO2 SLP228 T10611128=',
#  'SPECI KAAO 172149Z AUTO 02004KT 10SM SCT024 M07/M13 A3013\n           RMK AO2=',
#  'METAR KAAO 172054Z AUTO 36003KT 10SM OVC025 M07/M13 A3012\n           RMK AO2 SLP225 T10671128 55006=',
#  'METAR KAAO 171954Z AUTO 04005KT 10SM BKN024 M06/M13 A3012\n           RMK AO2 SLP225 T10611128=',
#  'SPECI KAAO 171950Z AUTO 03005KT 10SM BKN022 M07/M13 A3012\n           RMK AO2=',
#  'METAR KAAO 171854Z AUTO 00000KT 10SM CLR M08/M13 A3014 RMK\n           AO2 SLP233 T10781133=',
#  'METAR KAAO 171754Z AUTO 00000KT 10SM CLR M09/M14 A3016 RMK\n           AO2 SLP240 T10891139 11083 21150 50001=',
#  'METAR KAAO 171654Z AUTO 00000KT 10SM CLR M10/M14 A3017 RMK\n           AO2 SLP244 T11001144=',
#  'METAR KAAO 171554Z AUTO 04004KT 10SM CLR M11/M16 A3016 RMK\n           AO2 SLP241 T11111156=',
#  'SPECI KAAO 171533Z AUTO 03004KT 10SM FEW015 M12/M16 A3016\n           RMK AO2 T11171161=',
#  'SPECI KAAO 171510Z AUTO 01004KT 10SM BKN015 M13/M17 A3015\n           RMK AO2 T11281167=',
#  'METAR KAAO 171454Z AUTO 01003KT 10SM CLR M13/M17 A3015 RMK\n           AO2 SLP242 T11331172 53007=',
#  'METAR KAAO 171354Z AUTO 03003KT 10SM FEW030 M14/M17 A3014\n           RMK AO2 SLP238 T11441167=',
#  'METAR KAAO 171254Z AUTO 06003KT 10SM OVC080 M14/M17 A3013\n           RMK AO2 SLP235 T11391167=',
#  'METAR KAAO 171154Z AUTO 08003KT 10SM OVC080 M14/M16 A3013\n           RMK AO2 SLP235 60000 T11391161 11133 21144 52004=',
#  'METAR KAAO 171054Z AUTO 00000KT 10SM OVC080 M14/M17 A3013\n           RMK AO2 SLP234 T11391167=',
#  'METAR KAAO 170954Z AUTO 09003KT 10SM OVC080 M14/M17 A3012\n           RMK AO2 SLP231 T11391167=',
#  'METAR KAAO 170854Z AUTO 11003KT 9SM SCT080 M14/M17 A3012\n           RMK AO2 SNE04 SLP230 P0000 60000 T11391167 50001=',
#  'SPECI KAAO 170808Z AUTO 10003KT 6SM HZ SCT030 OVC080 M14/M17\n           A3012 RMK AO2 SNE04 P0000 T11391167=',
#  'METAR KAAO 170754Z AUTO 10004KT 3SM -SN OVC029 M14/M17 A3012\n           RMK AO2 SLP231 P0000 T11391167=',
#  'SPECI KAAO 170731Z AUTO 11004KT 3SM -SN BKN024 OVC080 M14/M17\n           A3012 RMK AO2 P0000 T11391167=',
#  'SPECI KAAO 170709Z AUTO 10004KT 2 1/2SM -SN OVC018 M14/M17\n           A3012 RMK AO2 P0000 T11391167=',
#  'SPECI KAAO 170702Z AUTO 10004KT 3SM -SN OVC020 M14/M17 A3012\n           RMK AO2 P0000 T11391167=',
#  'METAR KAAO 170654Z AUTO 10003KT 2 1/2SM -SN OVC024 M14/M17\n           A3012 RMK AO2 SLP231 P0000 T11391167=',
#  'SPECI KAAO 170644Z AUTO 10003KT 2 1/2SM -SN OVC030 M14/M17\n           A3011 RMK AO2 P0000 T11391167=',
#  'METAR KAAO 170554Z AUTO 10003KT 5SM -SN OVC060 M14/M17 A3011\n           RMK AO2 SNB11 SLP231 P0000 60000 T11391172 11133\n           21139 411331283 55002=',
#  'METAR KAAO 170454Z AUTO 12006KT 9SM OVC080 M14/M18 A3011\n           RMK AO2 SLP232 T11391183=',
#  'METAR KAAO 170354Z AUTO 11009KT 10SM OVC070 M13/M19 A3011\n           RMK AO2 SLP231 T11331189=',
#  'METAR KAAO 170254Z AUTO 11007KT 10SM OVC070 M13/M19 A3012\n           RMK AO2 SLP235 T11331189 51011=',
#  'METAR KAAO 170154Z AUTO 10006KT 10SM OVC065 M14/M19 A3012\n           RMK AO2 SLP238 T11391194=',
#  'METAR KAAO 170054Z AUTO 11008KT 10SM OVC065 M14/M19 A3010\n           RMK AO2 SLP233 T11391194=',
#  'METAR KAAO 162354Z AUTO 12008KT 10SM OVC065 M14/M20 A3009\n           RMK AO2 SLP227 T11391200 11133 21172 53003=',
#  'METAR KAAO 162254Z AUTO 09009KT 10SM BKN070 M14/M21 A3006\n           RMK AO2 SLP217 T11391206=',
#  'METAR KAAO 162154Z AUTO 09006KT 10SM CLR M14/M21 A3008 RMK\n           AO2 SLP224 T11391206=',
#  'METAR KAAO 162054Z AUTO 09007KT 10SM CLR M14/M21 A3007 RMK\n           AO2 SLP224 T11391206 56026=',
#  'METAR KAAO 161954Z AUTO 00000KT 10SM CLR M15/M21 A3011 RMK\n           AO2 SLP233 T11501211=',
#  'METAR KAAO 161854Z AUTO 10004KT 10SM CLR M16/M22 A3012 RMK\n           AO2 SLP239 T11611217=',
#  'METAR KAAO 161754Z AUTO 16005KT 10SM CLR M17/M23 A3016 RMK\n           AO2 SLP252 T11721228 11172 21283 58010=',
#  'METAR KAAO 161654Z AUTO 17005KT CLR M19/M23 A3017 RMK AO2\n           SLP257 T11891233 $=',
#  'METAR KAAO 161554Z AUTO 16006KT CLR M21/M24 A3018 RMK AO2\n           SLP260 T12061239 $=',
#  'METAR KAAO 161454Z AUTO 15003KT 10SM CLR M22/M24 A3019 RMK\n           AO2 SLP263 T12171244 53016=',
#  'METAR KAAO 161354Z AUTO 18004KT 10SM CLR M25/M28 A3017 RMK\n           AO2 SLP259 T12501278=',
#  'METAR KAAO 161254Z AUTO 15004KT 10SM CLR M26/M28 A3015 RMK\n           AO2 SLP253 T12561283=',
#  'METAR KAAO 161154Z AUTO 05003KT 10SM CLR M27/M29 A3014 RMK\n           AO2 SLP249 I6000 T12671289 11222 21272 58003=',
#  'METAR KAAO 161054Z AUTO 02003KT 10SM CLR M24/M27 A3014 RMK\n           AO2 SLP248 I1000 T12441267=',
#  'METAR KAAO 160954Z AUTO 00000KT 10SM CLR M25/M27 A3015 RMK\n           AO2 SLP251 T12501272=',
#  'METAR KAAO 160854Z AUTO 04003KT 10SM CLR M25/M28 A3015 RMK\n           AO2 SLP252 I1000 I3000 T12501278 58013=',
#  'METAR KAAO 160754Z AUTO 34004KT 10SM CLR M23/M26 A3017 RMK\n           AO2 SLP258 T12331261=',
#  'METAR KAAO 160654Z AUTO 34004KT 10SM CLR M23/M26 A3019 RMK\n           AO2 SLP265 T12281256=',
#  'METAR KAAO 160554Z AUTO 36004KT 10SM CLR M23/M26 A3019 RMK\n           AO2 SLP265 T12281256 11194 21228 411781228 58006=',
#  'METAR KAAO 160454Z AUTO 01005KT 10SM CLR M22/M25 A3020 RMK\n           AO2 SLP267 T12171250=',
#  'METAR KAAO 160354Z AUTO 35005KT 10SM OVC090 M20/M24 A3021\n           RMK AO2 SLP274 T12001239=',
#  'METAR KAAO 160254Z AUTO 35006KT 10SM OVC095 M20/M24 A3021\n           RMK AO2 SLP271 T12001239 55003=',
#  'METAR KAAO 160154Z AUTO 36006KT 10SM OVC100 M21/M24 A3021\n           RMK AO2 SLP272 T12061244=',
#  'METAR KAAO 160054Z AUTO 36007KT 10SM OVC110 M21/M25 A3021\n           RMK AO2 SLP273 T12061250=',
#  'METAR KAAO 152354Z AUTO 36011KT 10SM OVC110 M19/M24 A3022\n           RMK AO2 SLP275 60000 T11941239 11178 21206 56020=',
#  'METAR KAAO 152254Z AUTO 36012KT 10SM FEW033 FEW042 OVC110\n           M18/M23 A3024 RMK AO2 SNE2157 SLP280 P0000 T11831228=',
#  'METAR KAAO 152154Z AUTO 36013KT 7SM -SN SCT035 BKN044 OVC110\n           M18/M23 A3025 RMK AO2 SLP285 P0000 T11831228=',
#  'SPECI KAAO 152138Z AUTO 36012KT 3SM -SN BKN032 OVC040 M18/M23\n           A3025 RMK AO2 P0000 T11831228=',
#  'SPECI KAAO 152124Z AUTO 35012KT 2 1/2SM -SN BKN033 OVC042\n           M18/M23 A3026 RMK AO2 P0000 T11831233=',
#  'SPECI KAAO 152104Z AUTO 35013KT 1 3/4SM -SN BKN035 OVC044\n           M19/M23 A3027 RMK AO2 P0000 T11891233=',
#  'METAR KAAO 152054Z AUTO 35011KT 2SM -SN FEW028 BKN035 OVC044\n           M19/M23 A3028 RMK AO2 SLP294 P0000 60000 T11891233\n           56017=',
#  'SPECI KAAO 152048Z AUTO 34013KT 2SM -SN FEW026 BKN032 OVC041\n           M19/M23 A3028 RMK AO2 P0000=',
#  'SPECI KAAO 152033Z AUTO 33012KT 1 1/4SM -SN BKN020 BKN029\n           OVC036 M19/M23 A3029 RMK AO2 P0000 T11891233=',
#  'SPECI KAAO 152007Z AUTO 36010KT 3/4SM -SN BKN023 OVC030 M19/M23\n           A3029 RMK AO2 P0000 T11891233=',
#  'METAR KAAO 151954Z AUTO 01010KT 3/4SM -SN SCT024 OVC030 M19/M24\n           A3029 RMK AO2 SLP301 P0000 T11941239=',
#  'SPECI KAAO 151933Z AUTO 36011KT 1 1/2SM -SN BKN026 OVC034\n           M20/M24 A3031 RMK AO2 P0000 T12001244=',
#  'METAR KAAO 151854Z AUTO 34012KT -SN OVC041 M20/M25 A3033\n           RMK AO2 SNE06B21 SLP313 P0000 T12001250=',
#  'SPECI KAAO 151810Z AUTO 35013KT BKN032 OVC040 M20/M25 A3035\n           RMK AO2 SNE06 P0000 T12001250=',
#  'METAR KAAO 151754Z AUTO 01012KT -SN BKN028 OVC039 M21/M25\n           A3036 RMK AO2 SLP322 P0000 60000 T12061250 11206\n           21228 56016=',
#  'SPECI KAAO 151732Z AUTO 36013KT -SN BKN029 OVC035 M21/M26\n           A3037 RMK AO2 P0000 T12061256=',
#  'METAR KAAO 151654Z AUTO 01013KT -SN BKN038 OVC046 M21/M26\n           A3037 RMK AO2 SLP328 P0000 T12111261=',
#  'SPECI KAAO 151647Z AUTO 36015KT -SN BKN034 OVC044 M21/M26\n           A3037 RMK AO2 P0000 T12111261=',
#  'METAR KAAO 151554Z AUTO 36015KT -SN BKN024 BKN029 OVC038\n           M22/M27 A3037 RMK AO2 SLP330 P0000 T12221267 $=',
#  'SPECI KAAO 151540Z AUTO 36015KT -SN BKN024 BKN033 OVC043\n           M22/M27 A3038 RMK AO2 P0000 T12221267 $=',
#  'METAR KAAO 151454Z AUTO 36016KT -SN BKN032 OVC046 M23/M27\n           A3041 RMK AO2 SLP340 P0000 60000 T12281267 51003\n           $=',
#  'SPECI KAAO 151422Z AUTO 01012KT -SN OVC024 M23/M27 A3041\n           RMK AO2 P0000 T12281267 $=',
#  'METAR KAAO 151354Z AUTO 01012KT -SN OVC032 M23/M27 A3040\n           RMK AO2 SNB11 SLP338 P0000 T12281267 $=',
#  'METAR KAAO 151254Z AUTO 01010KT BKN060 OVC075 M23/M27 A3042\n           RMK AO2 SLP342 T12281267 $=',
#  'METAR KAAO 151154Z AUTO 01014KT 10SM FEW012 OVC090 M23/M27\n           A3040 RMK AO2 SLP334 60000 70002 T12281267 11222\n           21228 55022 $=',
#  'METAR KAAO 151054Z AUTO 36016KT FEW050 OVC100 M23/M27 A3039\n           RMK AO2 SNE23 SLP331 P0000 T12281272 $=',
#  'METAR KAAO 150954Z AUTO 36013KT 9SM -SN BKN070 OVC100 M23/M27\n           A3040 RMK AO2 SNB32 SLP337 P0000 T12281272 $=',
#  'METAR KAAO 150854Z AUTO 01011KT BKN090 OVC110 M23/M27 A3046\n           RMK AO2 SLP357 T12281267 58009 $=',
#  'METAR KAAO 150754Z AUTO 36011KT FEW120 M23/M27 A3048 RMK\n           AO2 SLP364 T12281272 $=',
#  'METAR KAAO 150654Z AUTO 35013KT 10SM CLR M23/M27 A3048 RMK\n           AO2 SLP363 T12281272 $=',
#  'METAR KAAO 150554Z AUTO 36013KT CLR M22/M27 A3049 RMK AO2\n           SLP366 T12221267 11178 21222 411611222 53001 $=',
#  'METAR KAAO 150454Z AUTO 36014KT 10SM CLR M22/M26 A3048 RMK\n           AO2 SLP363 T12221261=',
#  'SPECI KAAO 150402Z AUTO 36015G22KT 10SM SCT013 M22/M26 A3049\n           RMK AO2 T12171256=',
#  'METAR KAAO 150354Z AUTO 36015KT 10SM BKN013 M21/M26 A3049\n           RMK AO2 SLP366 T12111256=',
#  'SPECI KAAO 150341Z AUTO 36015KT 10SM BKN013 M21/M25 A3049\n           RMK AO2 T12111250=',
#  'METAR KAAO 150254Z AUTO 36016G25KT 10SM CLR M21/M25 A3049\n           RMK AO2 SLP363 T12061250 51007=',
#  'METAR KAAO 150154Z AUTO 36016KT 10SM FEW015 M19/M24 A3048\n           RMK AO2 SLP360 T11941244=',
#  'METAR KAAO 150054Z AUTO 36016KT 10SM SCT023 BKN100 M19/M23\n           A3048 RMK AO2 SLP357 T11891233=',
#  'SPECI KAAO 150039Z AUTO 36017KT 10SM FEW025 BKN100 M18/M23\n           A3047 RMK AO2 T11831233=',
#  'METAR KAAO 142354Z AUTO 36017KT 10SM SCT016 OVC024 M18/M23\n           A3046 RMK AO2 SNE21 SLP354 P0000 60002 T11781228\n           11161 21178 53005=',
#  'SPECI KAAO 142327Z AUTO 01016G24KT 4SM HZ SCT015 OVC024 M17/M22\n           A3045 RMK AO2 SNE21 P0000 T11721217=',
#  'SPECI KAAO 142318Z AUTO 36017KT 2SM -SN FEW017 BKN024 M17/M21\n           A3045 RMK AO2 P0000 T11721211=',
#  'METAR KAAO 142254Z AUTO 02017G24KT 6SM -SN BKN024 M17/M22\n           A3045 RMK AO2 SNE2158B50 SLP348 P0000 T11671217=',
#  'SPECI KAAO 142202Z AUTO 01017G25KT 9SM BKN025 M16/M22 A3045\n           RMK AO2 SNE2158 P0000 T11611222=',
#  'METAR KAAO 142154Z AUTO 01019G25KT 2 1/2SM -SN BKN025 M17/M22\n           A3045 RMK AO2 SNE13B46 SLP347 P0000 T11671222=',
#  'SPECI KAAO 142115Z AUTO 01014KT 3SM HZ SCT020 OVC024 M17/M21\n           A3046 RMK AO2 SNE13 P0000 T11671211=',
#  'METAR KAAO 142053Z AUTO 36016KT 1SM -SN BKN015 OVC035 M17/M21\n           A3045 RMK AO2 SLP349 P0001 60002 T11671206 56015=',
#  'SPECI KAAO 142052Z AUTO 36015KT 1SM -SN BKN013 BKN020 OVC028\n           M17/M21 A3045 RMK AO2 P0001=',
#  'SPECI KAAO 142043Z AUTO 01014G20KT 1/4SM +SN VV009 M17/M20\n           A3045 RMK AO2 P0001 T11671200=',
#  'METAR KAAO 141954Z AUTO 02014KT 1/2SM SN VV010 M17/M21 A3046\n           RMK AO2 SLP352 P0000 T11721206=',
#  'SPECI KAAO 141931Z AUTO 03011KT 1/4SM +SN VV009 M17/M21 A3047\n           RMK AO2 P0000 T11721206=',
#  'METAR KAAO 141854Z AUTO 01018G27KT 1/4SM +SN VV011 M17/M21\n           A3049 RMK AO2 PK WND 01027/1854 SLP361 P0001 T11721211=',
#  'SPECI KAAO 141817Z AUTO 02014G26KT 1/4SM +SN VV012 M17/M22\n           A3050 RMK AO2 PK WND 36026/1810 P0000 T11721217=',
#  'SPECI KAAO 141807Z AUTO 01017G23KT 1/2SM SN VV016 M17/M21\n           A3050 RMK AO2 P0000 T11721211=',
#  'METAR KAAO 141754Z AUTO 01022G27KT 1 1/4SM -SN BKN021 OVC027\n           M17/M22 A3050 RMK AO2 PK WND 02027/1754 SLP365\n           P0000 60000 T11721217 11161 21172 50000=',
#  'METAR KAAO 141654Z AUTO 03015G25KT 1SM -SN BKN018 OVC028\n           M17/M21 A3051 RMK AO2 PK WND 02027/1616 SNB02\n           SLP368 P0000 T11671211=',
#  'SPECI KAAO 141640Z AUTO 02018G24KT 3/4SM -SN FEW019 BKN026\n           OVC041 M17/M21 A3050 RMK AO2 PK WND 02027/1616\n           SNB02 P0000 T11671211=',
#  'SPECI KAAO 141634Z AUTO 01013KT 1 1/4SM -SN FEW026 BKN034\n           OVC050 M17/M21 A3050 RMK AO2 PK WND 02027/1616\n           SNB02 P0000 T11671211=',
#  'SPECI KAAO 141622Z AUTO 02017G27KT 2SM -SN BKN041 OVC050\n           M17/M22 A3051 RMK AO2 PK WND 02027/1616 SNB02\n           P0000 T11721222=',
#  'METAR KAAO 141554Z AUTO 01014G23KT 6SM HZ SCT060 OVC075 M17/M22\n           A3051 RMK AO2 PK WND 01026/1533 SNE29 SLP367 P0000\n           T11671217=',
#  'SPECI KAAO 141528Z AUTO 02016G25KT 6SM -SN OVC075 M17/M21\n           A3051 RMK AO2 P0000 T11671211=',
#  'SPECI KAAO 141521Z AUTO 03017G23KT 2 1/2SM -SN OVC075 M17/M21\n           A3050 RMK AO2 P0000 T11671206=',
#  'METAR KAAO 141454Z AUTO 03014G21KT 4SM -SN FEW026 OVC075\n           M17/M21 A3050 RMK AO2 PK WND 02027/1421 SLP364\n           P0000 60000 T11671206 53012=',
#  'SPECI KAAO 141423Z AUTO 02018G27KT 4SM -SN OVC080 M17/M21\n           A3048 RMK AO2 PK WND 02027/1421 P0000 T11671206=',
#  'METAR KAAO 141354Z AUTO 02015G23KT 2SM -SN FEW045 OVC080\n           M16/M21 A3049 RMK AO2 SLP359 P0000 T11611206=',
#  'SPECI KAAO 141325Z AUTO 01012KT 3SM -SN FEW028 OVC080 M16/M19\n           A3047 RMK AO2 P0000 T11611194=',
#  'SPECI KAAO 141304Z AUTO 02014G24KT 2SM -SN BKN034 OVC080\n           M16/M20 A3046 RMK AO2 P0000 T11611200=',
#  'METAR KAAO 141254Z AUTO 02015G22KT 3SM -SN OVC038 M16/M19\n           A3046 RMK AO2 SLP349 P0000 T11611194=',
#  'SPECI KAAO 141232Z AUTO 02013KT 2SM -SN OVC030 M16/M19 A3046\n           RMK AO2 P0000 T11611194=',
#  'METAR KAAO 141154Z AUTO 03011KT 1 1/2SM -SN OVC017 M16/M19\n           A3046 RMK AO2 SLP347 P0001 60001 70001 T11611194\n           11161 21167 50002=',
#  'SPECI KAAO 141150Z AUTO 03012G20KT 1 1/2SM -SN OVC017 M16/M19\n           A3046 RMK AO2 P0001=',
#  'SPECI KAAO 141132Z AUTO 02013KT 1SM -SN VV010 M16/M19 A3045\n           RMK AO2 P0001 T11611194=',
#  'SPECI KAAO 141116Z AUTO 02013G21KT 1/2SM SN VV008 M16/M19\n           A3046 RMK AO2 P0000 T11611194=',
#  'SPECI KAAO 141105Z AUTO 02014G22KT 3/4SM -SN VV011 M16/M19\n           A3045 RMK AO2 P0000 T11611194=',
#  'METAR KAAO 141054Z AUTO 01015KT 1SM -SN VV014 M16/M19 A3045\n           RMK AO2 SLP344 P0000 T11611194=',
#  'METAR KAAO 140954Z AUTO 03011KT 1 3/4SM -SN OVC026 M16/M20\n           A3045 RMK AO2 SLP344 P0000 T11611200=',
#  'SPECI KAAO 140951Z AUTO 03011KT 1 3/4SM -SN OVC028 M16/M20\n           A3045 RMK AO2 P0000=',
#  'SPECI KAAO 140921Z AUTO 03013G21KT 2 1/2SM -SN OVC031 M17/M21\n           A3046 RMK AO2 P0000 T11671206=',
#  'SPECI KAAO 140912Z AUTO 03016KT 1 3/4SM -SN OVC027 M17/M21\n           A3046 RMK AO2 P0000 T11671211=',
#  'SPECI KAAO 140903Z AUTO 04013G21KT 2SM -SN OVC029 M17/M21\n           A3046 RMK AO2 P0000 T11671211=',
#  'METAR KAAO 140854Z AUTO 04016KT 4SM -SN OVC040 M17/M22 A3045\n           RMK AO2 SNB33 SLP343 P0000 60000 T11671217 53005=',
#  'METAR KAAO 140754Z AUTO 04013G22KT 10SM OVC060 M17/M22 A3044\n           RMK AO2 SLP340 T11671217=',
#  'METAR KAAO 140654Z AUTO 04012G24KT 10SM FEW100 OVC120 M17/M22\n           A3043 RMK AO2 SLP339 T11671222=',
#  'METAR KAAO 140554Z AUTO 03013KT 10SM CLR M17/M22 A3043 RMK\n           AO2 SLP338 T11671217 11128 21167 411061183 51019=',
#  'METAR KAAO 140454Z AUTO 02011KT 10SM CLR M17/M22 A3042 RMK\n           AO2 SLP335 T11671217=',
#  'METAR KAAO 140354Z AUTO 02012KT 10SM CLR M16/M21 A3039 RMK\n           AO2 SLP327 T11611211=',
#  'METAR KAAO 140254Z AUTO 03015G21KT 10SM CLR M16/M21 A3037\n           RMK AO2 SLP321 T11561211 51013=',
#  'METAR KAAO 140154Z AUTO 03012G20KT 10SM CLR M14/M19 A3037\n           RMK AO2 SLP320 T11441194=',
#  'SPECI KAAO 140107Z AUTO 02008KT 10SM SCT027 M14/M19 A3036\n           RMK AO2 T11391189=',
#  'METAR KAAO 140054Z AUTO 01009KT 10SM BKN026 M13/M19 A3036\n           RMK AO2 SLP316 T11331189=',
#  'METAR KAAO 132354Z AUTO 03010KT 10SM BKN027 M13/M18 A3033\n           RMK AO2 SLP305 T11281183 11106 21128 55006=',
#  'SPECI KAAO 132326Z AUTO 03011KT 10SM SCT026 M12/M18 A3033\n           RMK AO2 T11221183=',
#  'METAR KAAO 132254Z AUTO 02013G19KT 10SM BKN026 M12/M18 A3033\n           RMK AO2 SLP303 T11221178=',
# ...
#  'METAR KAAO 310754Z AUTO 33022G31KT 10SM OVC014 01/M02 A3003\n           RMK AO2 PK WND 33034/0724 SLP178 T00061022=',
#  'METAR KAAO 310654Z AUTO 33018G28KT 10SM OVC014 01/M02 A3000\n           RMK AO2 PK WND 33031/0610 SLP165 T00061022=',
#  'METAR KAAO 310554Z AUTO 33018G30KT 10SM OVC012 01/M01 A2996\n           RMK AO2 PK WND 33031/0519 SLP153 T00111011 10033\n           20011 401060011 51038=',
#  'METAR KAAO 310454Z AUTO 34020G32KT 9SM OVC010 02/M01 A2992\n           RMK AO2 PK WND 35032/0401 SLP140 T00171011=',
#  'METAR KAAO 310354Z AUTO 33021G30KT 8SM OVC011 02/M01 A2989\n           RMK AO2 PK WND 33030/0351 SLP129 T00221006=',
#  'METAR KAAO 310254Z AUTO 34019G29KT 7SM OVC010 02/00 A2985\n           RMK AO2 PK WND 33036/0157 SLP113 T00220000 51029=',
#  'SPECI KAAO 310251Z AUTO 33018G32KT 8SM OVC010 02/00 A2984\n           RMK AO2 PK WND 33036/0157=',
#  'METAR KAAO 310154Z AUTO 33023G37KT 8SM OVC009 02/01 A2981\n           RMK AO2 PK WND 34037/0151 SLP100 T00220006=',
#  'METAR KAAO 310054Z AUTO 33024G32KT 7SM OVC007 03/01 A2976\n           RMK AO2 PK WND 31032/0004 CIG 007V011 SLP082 T00280011=',
#  'METAR KAAO 302354Z AUTO 32017G26KT 5SM BR OVC007 03/02 A2970\n           RMK AO2 PK WND 32029/2334 SLP063 60023 T00330017\n           10106 20033 51042=',
#  'SPECI KAAO 302307Z AUTO 32016KT 6SM BR OVC009 03/02 A2965\n           RMK AO2 CIG 008V012 T00330017=',
#  'METAR KAAO 302254Z AUTO 31016KT 7SM OVC010 03/02 A2964 RMK\n           AO2 PK WND 32030/2221 PRESRR SLP042 T00330017=',
#  'SPECI KAAO 302252Z AUTO 32017KT 7SM OVC010 03/02 A2964 RMK\n           AO2 PK WND 32030/2221=',
#  'METAR KAAO 302154Z AUTO 31015KT 7SM OVC008 06/04 A2957 RMK\n           AO2 PK WND 33035/2057 RAE26 CIG 007V012 PRESRR\n           SLP017 P0000 T00560039=',
#  'SPECI KAAO 302137Z AUTO 31020G28KT 9SM BKN008 BKN036 OVC055\n           07/05 A2955 RMK AO2 PK WND 33035/2057 RAE26 CIG\n           007V012 PRESRR P0000 T00670050=',
#  'SPECI KAAO 302116Z AUTO 33021G30KT 9SM -RA FEW021 BKN037\n           OVC055 07/05 A2952 RMK AO2 PK WND 33035/2057 P0000\n           T00720050=',
#  'METAR KAAO 302054Z AUTO 33023G33KT 10SM -RA SCT008 OVC020\n           07/05 A2950 RMK AO2 PK WND 31038/2036 SLP992 P0003\n           60023 T00720050 53017=',
#  'SPECI KAAO 302050Z AUTO 33024G33KT 9SM -RA SCT008 OVC020\n           07/05 A2950 RMK AO2 PK WND 31038/2036 P0003=',
#  'SPECI KAAO 302036Z AUTO 31024G38KT 6SM -RA BR SCT005 BKN010\n           OVC026 09/08 A2947 RMK AO2 PK WND 31038/2036 P0003\n           T00890083=',
#  'SPECI KAAO 302029Z AUTO 30009KT 7SM -RA SCT007 BKN017 OVC030\n           10/09 A2946 RMK AO2 CIG 011V021 P0002 T01000089=',
#  'SPECI KAAO 302019Z AUTO 31011KT 8SM -RA BKN007 BKN022 OVC046\n           11/09 A2946 RMK AO2 CIG 004V013 P0002 T01060089=',
#  'SPECI KAAO 302012Z AUTO 28006KT 9SM -RA SCT009 BKN021 OVC034\n           11/09 A2945 RMK AO2 P0001 T01060094=',
#  'SPECI KAAO 302003Z AUTO 26006KT 5SM -RA BR SCT007 BKN014\n           OVC035 11/09 A2945 RMK AO2 P0001 T01060089=',
#  'METAR KAAO 301954Z AUTO 26004KT 7SM -RA FEW005 BKN022 OVC035\n           10/09 A2945 RMK AO2 SLP973 P0006 T01000089=',
#  'SPECI KAAO 301950Z AUTO 25004KT 10SM -RA FEW005 BKN028 OVC042\n           10/09 A2945 RMK AO2 CIG 020V034 P0006=',
#  'SPECI KAAO 301941Z AUTO 22004KT 10SM -RA BKN015 BKN043 OVC060\n           10/09 A2945 RMK AO2 P0006 T01000094=',
#  'SPECI KAAO 301913Z AUTO 19007KT 6SM -RA BR FEW005 SCT025\n           OVC060 10/09 A2945 RMK AO2 P0005 T01000089=',
#  'SPECI KAAO 301905Z AUTO 19006KT 3SM RA BR SCT005 BKN022 OVC060\n           10/09 A2946 RMK AO2 P0004 T01000089=',
#  'METAR KAAO 301854Z AUTO 20006KT 2 1/2SM +RA BR BKN005 BKN024\n           OVC032 09/09 A2946 RMK AO2 SLP977 P0014 T00940089=',
#  'SPECI KAAO 301820Z AUTO 20007KT 5SM -RA BR OVC006 09/08 A2948\n           RMK AO2 CIG 004V009 P0005 T00940083=',
#  'SPECI KAAO 301813Z AUTO 16006KT 2 1/2SM -RA BR OVC006 09/08\n           A2948 RMK AO2 P0004 T00940083=',
#  'METAR KAAO 301754Z AUTO 19008KT 9SM -RA OVC006 10/08 A2949\n           RMK AO2 PK WND 13026/1703 WSHFT 1709 RAE10B53\n           SLP987 P0000 60072 T01000083 10100 20089 55020=',
#  'SPECI KAAO 301729Z AUTO 21008G18KT 10SM BKN006 OVC075 10/09\n           A2950 RMK AO2 PK WND 13026/1703 WSHFT 1709 RAE10\n           CIG 005V010 P0000 T01000089=',
#  'SPECI KAAO 301722Z AUTO 22012KT 10SM BKN006 OVC075 10/08\n           A2951 RMK AO2 PK WND 13026/1703 WSHFT 1702 RAE10\n           P0000 T01000083=',
#  'METAR KAAO 301654Z AUTO 13014G21KT 10SM -RA OVC005 09/08\n           A2948 RMK AO2 CIG 004V009 PRESFR SLP982 P0005\n           T00940083=',
#  'METAR KAAO 301554Z AUTO 15009KT 5SM RA BR OVC006 09/08 A2953\n           RMK AO2 RAB06 CIG 004V009 PRESFR SLP001 P0012\n           T00940083=',
#  'SPECI KAAO 301540Z AUTO 16011G20KT 4SM RA BR OVC005 09/08\n           A2955 RMK AO2 RAB06 CIG 004V009 PRESFR P0009 T00940083=',
#  'SPECI KAAO 301529Z AUTO 16012G23KT 2SM +RA BR OVC005 09/08\n           A2957 RMK AO2 RAB06 P0007 T00940083=',
#  'METAR KAAO 301454Z AUTO 14013G22KT 8SM OVC006 09/08 A2955\n           RMK AO2 PK WND 14027/1437 RAE50 SLP009 P0009 60055\n           T00890078 58022=',
#  'SPECI KAAO 301220Z AUTO 19023G38KT 3SM +RA BR FEW008 BKN050\n           OVC070 09/08 A2965 RMK AO2 PK WND 21043/1209 P0011\n           T00940078=',
#  'METAR KAAO 301154Z AUTO 19023G35KT 6SM -RA BR SCT055 BKN070\n           OVC095 09/08 A2962 RMK AO2 PK WND 19036/1139 RAB22\n           SLP031 P0006 60006 70006 T00940078 10100 20083\n           55021=',
#  'METAR KAAO 301054Z AUTO 18011G21KT 10SM OVC100 10/06 A2960\n           RMK AO2 PK WND 17026/1018 PRESFR SLP025 T01000061=',
#  'METAR KAAO 300954Z AUTO 18014G22KT 10SM FEW110 10/05 A2965\n           RMK AO2 SLP040 T01000050=',
#  'METAR KAAO 300854Z AUTO 19016KT 10SM CLR 09/04 A2969 RMK\n           AO2 SLP054 T00940044 58020=',
#  'METAR KAAO 300754Z AUTO 18014G23KT 10SM CLR 09/04 A2971 RMK\n           AO2 SLP063 T00890039=',
#  'METAR KAAO 300654Z AUTO 18016KT 10SM CLR 09/03 A2973 RMK\n           AO2 PK WND 18029/0631 SLP070 T00890033=',
#  'METAR KAAO 300554Z AUTO 19020G29KT 10SM CLR 09/03 A2975 RMK\n           AO2 PK WND 19032/0537 SLP076 T00940033 10100 20089\n           401000006 58014=',
#  'METAR KAAO 300454Z AUTO 19019G29KT 10SM CLR 09/03 A2976 RMK\n           AO2 PK WND 19032/0408 SLP082 T00890028=',
#  'METAR KAAO 300354Z AUTO 18020G29KT 10SM CLR 09/02 A2978 RMK\n           AO2 PK WND 19031/0310 SLP088 T00940022=',
#  'METAR KAAO 300254Z AUTO 18019G29KT 10SM CLR 10/02 A2979 RMK\n           AO2 PK WND 18033/0219 SLP092 T01000022 58020=',
#  'METAR KAAO 300154Z AUTO 19021G27KT 10SM CLR 10/02 A2984 RMK\n           AO2 PK WND 18029/0141 SLP110 T01000017=',
#  'METAR KAAO 300054Z AUTO 18012G20KT 10SM CLR 10/02 A2986 RMK\n           AO2 SLP117 T01000017=',
#  'METAR KAAO 292354Z AUTO 17011KT 10SM CLR 09/01 A2985 RMK\n           AO2 SLP115 T00940011 10100 20072 56019=',
#  'METAR KAAO 292254Z AUTO 17016G23KT 10SM CLR 10/01 A2986 RMK\n           AO2 PK WND 18027/2214 SLP117 T01000011=',
#  'METAR KAAO 292154Z AUTO 17016G22KT 10SM CLR 09/01 A2988 RMK\n           AO2 PK WND 18031/2104 SLP124 T00940006=',
#  'METAR KAAO 292054Z AUTO 18017G27KT 10SM CLR 09/01 A2991 RMK\n           AO2 PK WND 19027/2053 SLP134 T00940006 58036=',
#  'METAR KAAO 291954Z AUTO 18015G26KT 10SM CLR 09/01 A2994 RMK\n           AO2 PK WND 17031/1907 SLP146 T00890006=',
#  'METAR KAAO 291854Z AUTO 17019G30KT 10SM CLR 08/00 A2999 RMK\n           AO2 PK WND 18032/1841 SLP163 T00780000=',
#  'METAR KAAO 291754Z AUTO 18016KT 10SM CLR 07/M01 A3002 RMK\n           AO2 PK WND 20030/1716 SLP173 T00721006 10078 20006\n           58024=',
#  'METAR KAAO 291654Z AUTO 18015G25KT 10SM CLR 06/M01 A3005\n           RMK AO2 PK WND 17030/1639 SLP186 T00611011=',
#  'METAR KAAO 291554Z AUTO 18017G26KT 10SM CLR 04/M02 A3006\n           RMK AO2 PK WND 17028/1502 SLP190 T00441017=',
#  'METAR KAAO 291454Z AUTO 18017G27KT 10SM CLR 02/M02 A3009\n           RMK AO2 PK WND 18027/1440 SLP201 T00221022 56013=',
#  'METAR KAAO 291354Z AUTO 18017G24KT 10SM CLR 01/M03 A3009\n           RMK AO2 PK WND 17026/1334 SLP203 T00111028=',
#  'METAR KAAO 291254Z AUTO 18016G25KT 10SM CLR 01/M03 A3011\n           RMK AO2 PK WND 19027/1236 SLP210 T00061028=',
#  'METAR KAAO 291154Z AUTO 18014G21KT 10SM CLR 01/M03 A3013\n           RMK AO2 SLP216 T00061033 10011 20006 56020=',
#  'METAR KAAO 291054Z AUTO 18014G23KT 10SM CLR 01/M03 A3014\n           RMK AO2 PK WND 18026/0955 SLP217 T00111033=',
#  'METAR KAAO 290954Z AUTO 20015G23KT 10SM CLR 01/M03 A3016\n           RMK AO2 SLP223 T00111033=',
#  'METAR KAAO 290854Z AUTO 19013KT 10SM CLR 01/M03 A3019 RMK\n           AO2 SLP235 T00111033 58021=',
#  'METAR KAAO 290754Z AUTO 19014KT 10SM CLR 01/M03 A3022 RMK\n           AO2 SLP244 T00111033=',
#  'METAR KAAO 290654Z AUTO 18012KT 10SM CLR 01/M04 A3024 RMK\n           AO2 SLP253 T00061039=',
#  'METAR KAAO 290554Z AUTO 19014KT 10SM CLR 01/M04 A3026 RMK\n           AO2 SLP261 T00111039 10017 20006 400441061 56009=',
#  'METAR KAAO 290454Z AUTO 18013KT 10SM CLR 01/M04 A3027 RMK\n           AO2 SLP264 T00111039=',
#  'METAR KAAO 290354Z AUTO 17013KT 10SM CLR 01/M04 A3027 RMK\n           AO2 SLP266 T00061039=',
#  'METAR KAAO 290254Z AUTO 18013KT 10SM CLR 01/M04 A3029 RMK\n           AO2 SLP272 T00111039 56017=',
#  'METAR KAAO 290154Z AUTO 17011KT 10SM CLR 01/M04 A3031 RMK\n           AO2 SLP279 T00111039=',
#  'METAR KAAO 290054Z AUTO 17012KT 10SM CLR 01/M04 A3032 RMK\n           AO2 SLP283 T00111039=',
#  'METAR KAAO 282354Z AUTO 17010KT 10SM CLR 02/M04 A3034 RMK\n           AO2 SLP290 T00171044 10044 20000 58016=',
#  'METAR KAAO 282254Z AUTO 17011G22KT 10SM CLR 03/M04 A3036\n           RMK AO2 SLP296 T00281044=',
#  'METAR KAAO 282154Z AUTO 18013KT 10SM CLR 04/M04 A3037 RMK\n           AO2 SLP299 T00391044=',
#  'METAR KAAO 282054Z AUTO 16013KT 10SM CLR 04/M04 A3039 RMK\n           AO2 SLP305 T00441039 56037=',
#  'METAR KAAO 281954Z AUTO 17016G23KT 10SM CLR 03/M04 A3040\n           RMK AO2 SLP312 T00331044=',
#  'METAR KAAO 281854Z AUTO 16012G20KT 10SM CLR 02/M05 A3044\n           RMK AO2 SLP326 T00171050=',
#  'METAR KAAO 281754Z AUTO 16013KT 10SM CLR 00/M06 A3050 RMK\n           AO2 SLP347 T00001056 10006 21050 58010=',
#  'SPECI KAAO 281716Z AUTO 17015G22KT 10SM SCT015 00/M06 A3052\n           RMK AO2 T00001056=',
#  'SPECI KAAO 281704Z AUTO 16014KT 10SM BKN015 M01/M06 A3052\n           RMK AO2 T10061056=',
#  'METAR KAAO 281654Z AUTO 16011KT 10SM BKN013 M02/M06 A3052\n           RMK AO2 SLP356 T10171061=',
#  'METAR KAAO 281554Z AUTO 17014G19KT 10SM OVC011 M03/M07 A3053\n           RMK AO2 SLP358 T10331067=',
#  'METAR KAAO 281454Z AUTO 16013G19KT 10SM OVC011 M04/M07 A3053\n           RMK AO2 SLP361 T10391072 55004=',
#  'METAR KAAO 281354Z AUTO 16010KT 10SM OVC011 M04/M07 A3053\n           RMK AO2 SLP358 T10441072=',
#  'METAR KAAO 281254Z AUTO 14010KT 10SM OVC012 M05/M08 A3051\n           RMK AO2 SLP355 T10501078=',
#  'METAR KAAO 281154Z AUTO 17007KT 10SM OVC012 M05/M08 A3054\n           RMK AO2 SLP364 T10501078 11044 21061 53000=',
#  'METAR KAAO 281054Z AUTO 15008KT 10SM OVC011 M04/M08 A3054\n           RMK AO2 SLP363 T10441078=',
#  'METAR KAAO 280954Z AUTO 17007KT 10SM OVC011 M05/M08 A3054\n           RMK AO2 SLP362 T10501078=',
#  'METAR KAAO 280854Z AUTO 16009KT 10SM OVC011 M05/M08 A3054\n           RMK AO2 SLP363 T10501078 53009=',
#  'METAR KAAO 280754Z AUTO 13007KT 10SM OVC011 M06/M08 A3053\n           RMK AO2 SLP360 T10561083=',
#  'METAR KAAO 280654Z AUTO 12007KT 10SM OVC011 M06/M08 A3051\n           RMK AO2 SLP353 T10561083=',
#  'METAR KAAO 280554Z AUTO 11009KT 10SM OVC011 M06/M09 A3052\n           RMK AO2 SLP355 T10611089 11044 21067 410281067\n           53005=',
#  'METAR KAAO 280454Z AUTO 09004KT 10SM OVC011 M07/M09 A3051\n           RMK AO2 SLP354 T10671094=',
#  'METAR KAAO 280354Z AUTO 07007KT 10SM OVC012 M06/M09 A3050\n           RMK AO2 SLP351 T10611089=',
#  'METAR KAAO 280254Z AUTO 04004KT 10SM OVC013 M06/M09 A3050\n           RMK AO2 SLP350 T10611094 50008=',
#  'SPECI KAAO 280216Z AUTO 06006KT 10SM OVC014 M06/M09 A3050\n           RMK AO2 T10561089=',
#  'METAR KAAO 280154Z AUTO 05003KT 10SM OVC015 M05/M09 A3051\n           RMK AO2 SLP353 T10501089=',
#  'METAR KAAO 280054Z AUTO 00000KT 10SM OVC016 M05/M09 A3049\n           RMK AO2 SLP345 T10501089=',
#  'METAR KAAO 272354Z AUTO 02005KT 10SM OVC017 M04/M09 A3048\n           RMK AO2 SLP341 T10441089 11028 21050 53015=',
#  'METAR KAAO 272254Z AUTO 03005KT 10SM OVC017 M04/M09 A3046\n           RMK AO2 SLP333 T10391089=',
#  'METAR KAAO 272154Z AUTO 01008KT 10SM OVC018 M04/M09 A3044\n           RMK AO2 SLP326 T10391089=',
#  'METAR KAAO 272054Z AUTO 34008KT 10SM OVC019 M04/M09 A3043\n           RMK AO2 SLP324 T10391089 53007=',
#  'METAR KAAO 271954Z AUTO 31009KT 10SM OVC020 M04/M09 A3043\n           RMK AO2 SLP324 T10391089=',
#  'METAR KAAO 271854Z AUTO 31011KT 10SM BKN018 M04/M09 A3040\n           RMK AO2 SLP315 T10391089 $=',
#  'SPECI KAAO 271819Z AUTO 33010KT 10SM OVC015 M04/M08 A3040\n           RMK AO2 T10391083=',
#  'METAR KAAO 271754Z AUTO 29008KT 10SM OVC014 M04/M09 A3041\n           RMK AO2 SLP318 T10441089 11044 21056 51028=',
#  'METAR KAAO 271654Z AUTO 34013KT 10SM OVC013 M05/M09 A3039\n           RMK AO2 SLP312 T10501089=',
#  'SPECI KAAO 271642Z AUTO 33010KT 10SM OVC014 M04/M08 A3038\n           RMK AO2 T10441083=',
#  'METAR KAAO 271554Z AUTO 32011KT 10SM OVC015 M04/M08 A3036\n           RMK AO2 SLP301 T10441083=',
#  'SPECI KAAO 271519Z AUTO 32011KT 10SM SCT009 OVC017 M04/M08\n           A3033 RMK AO2 T10441078=',
#  'METAR KAAO 271454Z AUTO 32009KT 10SM OVC009 M05/M08 A3032\n           RMK AO2 SLP288 T10501078 51031=',
#  'METAR KAAO 271354Z AUTO 31008KT 10SM OVC009 M05/M08 A3029\n           RMK AO2 SLP278 T10501078=',
#  'SPECI KAAO 271335Z AUTO 32009KT 10SM BKN009 OVC034 M05/M08\n           A3029 RMK AO2 T10501078=',
#  'SPECI KAAO 271327Z AUTO 33008KT 10SM BKN010 OVC034 M05/M08\n           A3028 RMK AO2 T10501078=',
#  'METAR KAAO 271254Z AUTO 34008KT 10SM SCT009 OVC020 M05/M08\n           A3026 RMK AO2 SLP267 T10501078=',
#  'SPECI KAAO 271252Z AUTO 34009KT 10SM SCT009 OVC020 M05/M08\n           A3026 RMK AO2=',
#  'SPECI KAAO 271239Z AUTO 34010KT 10SM BKN010 OVC016 M05/M08\n           A3025 RMK AO2 CIG 008V013 T10501078=',
#  'SPECI KAAO 271218Z AUTO 34010KT 10SM OVC008 M05/M07 A3024\n           RMK AO2 T10501072=',
#  'METAR KAAO 271154Z AUTO 34009KT 10SM BKN010 OVC016 M04/M07\n           A3023 RMK AO2 CIG 008V013 SLP255 T10441067 11039\n           21044 53015=',
#  'SPECI KAAO 271133Z AUTO 32008KT 10SM BKN010 OVC015 M04/M07\n           A3022 RMK AO2 CIG 008V012 T10441067=',
#  'SPECI KAAO 271120Z AUTO 33008KT 10SM BKN008 OVC015 M04/M07\n           A3021 RMK AO2 T10441067=',
#  'SPECI KAAO 271113Z AUTO 33006KT 10SM SCT010 OVC015 M04/M07\n           A3021 RMK AO2 T10441067=',
#  'SPECI KAAO 271104Z AUTO 35008KT 10SM OVC013 M04/M07 A3021\n           RMK AO2 T10441067=',
#  'METAR KAAO 271054Z AUTO 34006KT 10SM FEW010 OVC015 M04/M07\n           A3020 RMK AO2 SLP247 T10441072=',
#  'SPECI KAAO 271020Z AUTO 01004KT 10SM OVC015 M04/M07 A3019\n           RMK AO2 T10391072=',
#  'METAR KAAO 270954Z AUTO 03004KT 10SM OVC013 M04/M07 A3019\n           RMK AO2 SLP240 T10391072=',
#  'METAR KAAO 270854Z AUTO 05004KT 10SM OVC014 M04/M07 A3018\n           RMK AO2 SLP239 T10441072 52007=',
#  'SPECI KAAO 270850Z AUTO 03004KT 10SM OVC014 M04/M07 A3018\n           RMK AO2=',
#  'SPECI KAAO 270801Z AUTO 08005KT 10SM BKN016 OVC020 M04/M07\n           A3016 RMK AO2 T10441072=',
#  'METAR KAAO 270754Z AUTO 06005KT 10SM BKN014 OVC020 M04/M07\n           A3016 RMK AO2 SLP232 T10441072=',
#  'SPECI KAAO 270736Z AUTO 06008KT 10SM OVC014 M04/M07 A3015\n           RMK AO2 T10441072=',
#  'SPECI KAAO 270709Z AUTO 03004KT 10SM OVC015 M04/M07 A3016\n           RMK AO2 T10441072=',
#  'METAR KAAO 270654Z AUTO 03004KT 10SM OVC014 M04/M07 A3016\n           RMK AO2 SLP232 T10441072=',
#  'METAR KAAO 270554Z AUTO 05004KT 10SM OVC012 M04/M07 A3015\n           RMK AO2 SLP229 60000 T10441072 11039 21044 410171050\n           53006=',
#  'METAR KAAO 270454Z AUTO 02004KT 10SM OVC012 M04/M07 A3014\n           RMK AO2 SLP224 T10441072=',
#  ...]
