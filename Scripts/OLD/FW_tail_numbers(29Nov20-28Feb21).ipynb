# %%
#load packages
import pandas as pd 
import numpy as np
import fuzzymatcher
pd.set_option('display.max_columns', 999)

# %%
#load data and convert dates to datetime
fw = pd.read_csv("../Datasets/29Nov20-28Feb21/FW_tail_numbers (29Nov20-28Feb21).csv")
fw.head()
# Out:
#   tail_number       date aircraft              origin  \
# 0      N7025P  28-Feb-21  Unknown       Near Bend, OR
# 1      N7025P  28-Feb-21  Unknown     Tews Fld (CA53)
# 2      N7025P  21-Feb-21  Unknown    Near Lincoln, CA
# 3      N7025P  21-Feb-21  Unknown  Near Red Bluff, CA
# 4      N7025P  24-Dec-20  Unknown  Near Red Bluff, CA
#
#                  origin_location            destination  \
# 0          L 43.95194 -121.28694                    NaN
# 1  Tews Fld (Redding, CA) - CA53          Near Bend, OR
# 2          L 38.93333 -121.41667    Redding Muni (KRDD)
# 3          L 40.24000 -122.19083    Near Marysville, CA
# 4          L 40.28861 -122.05861  Near Emigrant Gap, CA
#
#                 destination_location               departure  \
# 0                            Unknown  First seen 04:59PM PST
# 1              L 43.81944 -121.37583             01:36PM PST
# 2  Redding Muni (Redding, CA) - KRDD  First seen 03:02PM PST
# 3              L 38.94750 -121.52250  First seen 12:46PM PST
# 4              L 39.77972 -120.52333  First seen 09:25AM PST
#
#                  arrival  duration  \
# 0                    NaN  En Route
# 1  Last seen 03:01PM PST      1:24
# 2  Last seen 03:49PM PST      0:47
# 3  Last seen 01:20PM PST      0:33
# 4  Last seen 10:02AM PST      0:36
#
#                                      medical_service
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...
# 2  A PRECIOUS LIFE FLIGHT LLC                    ...
# 3  A PRECIOUS LIFE FLIGHT LLC                    ...
# 4  A PRECIOUS LIFE FLIGHT LLC                    ...

# %%
# Remove useless words
fw = fw.replace(regex={'Near ':'', 'First seen ':'', 'Last seen ':'', 'En Route':None, 'Unknown':None, 'Diverted':None, ' ':' '})

# %%
# check for duplicates
fw.duplicated().sum()
# Out:
# 0

# %%
# check for null values
fw.isna().sum()
# Out:
# tail_number               0
# date                      0
# aircraft                 26
# origin                    0
# origin_location           0
# destination               2
# destination_location      2
# departure                 0
# arrival                 229
# duration                232
# medical_service           0
# dtype: int64

# %%
# split origin_Latitude and origin_Longitude
fw['origin_Latitude'] = fw[fw.origin_location.str.startswith('L ')].origin_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[0]
fw['origin_Longitude'] = fw[fw.origin_location.str.startswith('L ')].origin_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[1]

# %%
# split destination_Latitude and destination_Longitude
fw['destination_Latitude'] = fw[fw.destination_location.str.startswith('L ', na=False)].destination_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[0]
fw['destination_Longitude'] = fw[fw.destination_location.str.startswith('L ', na=False)].destination_location.replace(regex={'L ':''}).str.split(" ", n = 1, expand = True)[1]

# %%
# convert to numeric
fw['origin_Latitude'] = pd.to_numeric(fw.origin_Latitude, errors='coerce')
fw['origin_Longitude'] = pd.to_numeric(fw.origin_Longitude, errors='coerce')

fw['destination_Latitude'] = pd.to_numeric(fw.destination_Latitude, errors='coerce')
fw['destination_Longitude'] = pd.to_numeric(fw.destination_Longitude, errors='coerce')

# %%
# split ICAO_code
fw['ICAO_code_origin'] = fw[fw.origin_Latitude.isna()].origin_location.str.rsplit(" - ", n = 1, expand = True)[1]
fw['ICAO_code_destination'] = fw[fw.destination_Latitude.isna()].destination_location.str.rsplit(" - ", n = 1, expand = True)[1]

# %%
fw.head()
# Out:
#   tail_number       date aircraft           origin  \
# 0      N7025P  28-Feb-21     None         Bend, OR
# 1      N7025P  28-Feb-21     None  Tews Fld (CA53)
# 2      N7025P  21-Feb-21     None      Lincoln, CA
# 3      N7025P  21-Feb-21     None    Red Bluff, CA
# 4      N7025P  24-Dec-20     None    Red Bluff, CA
#
#                  origin_location          destination  \
# 0          L 43.95194 -121.28694                  NaN
# 1  Tews Fld (Redding, CA) - CA53             Bend, OR
# 2          L 38.93333 -121.41667  Redding Muni (KRDD)
# 3          L 40.24000 -122.19083       Marysville, CA
# 4          L 40.28861 -122.05861     Emigrant Gap, CA
#
#                 destination_location    departure      arrival duration  \
# 0                               None  04:59PM PST          NaN     None
# 1              L 43.81944 -121.37583  01:36PM PST  03:01PM PST     1:24
# 2  Redding Muni (Redding, CA) - KRDD  03:02PM PST  03:49PM PST     0:47
# 3              L 38.94750 -121.52250  12:46PM PST  01:20PM PST     0:33
# 4              L 39.77972 -120.52333  09:25AM PST  10:02AM PST     0:36
#
#                                      medical_service  origin_Latitude  \
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...         43.95194
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...              NaN
# 2  A PRECIOUS LIFE FLIGHT LLC                    ...         38.93333
# 3  A PRECIOUS LIFE FLIGHT LLC                    ...         40.24000
# 4  A PRECIOUS LIFE FLIGHT LLC                    ...         40.28861
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0        -121.28694                   NaN                    NaN
# 1               NaN              43.81944             -121.37583
# 2        -121.41667                   NaN                    NaN
# 3        -122.19083              38.94750             -121.52250
# 4        -122.05861              39.77972             -120.52333
#
#   ICAO_code_origin ICAO_code_destination
# 0              NaN                  None
# 1             CA53                   NaN
# 2              NaN                  KRDD
# 3              NaN                   NaN
# 4              NaN                   NaN

# %%
# load airport code data
airport_codes = pd.read_csv("../Datasets/Airports/airport-codes.csv")
airport_codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %%
# check duplicates
airport_codes.duplicated(subset=['ident']).sum()
# Out:
# 0

# %%
# split coordinates and convert to numeric
airport_codes["Latitude"] = pd.to_numeric(airport_codes.coordinates.str.split(', ', n=1, expand=True)[1])
airport_codes["Longitude"] = pd.to_numeric(airport_codes.coordinates.str.split(', ', n=1, expand=True)[0])

# %%
# merge origin airport information
fw = fw.merge(airport_codes[['ident', 'iata_code', 'Latitude', 'Longitude']].add_suffix('_origin'),
         how='left', left_on='ICAO_code_origin', right_on='ident_origin')

# %%
# merge destination airport information
fw = fw.merge(airport_codes[['ident', 'iata_code', 'Latitude', 'Longitude']].add_suffix('_destination'),
         how='left', left_on='ICAO_code_destination', right_on='ident_destination')

# %%
# merge 2 columns
fw.origin_Latitude = fw.origin_Latitude.fillna(0) + fw.Latitude_origin.fillna(0)
fw.origin_Longitude = fw.origin_Longitude.fillna(0) + fw.Longitude_origin.fillna(0)

fw.destination_Latitude = fw.destination_Latitude.fillna(0) + fw.Latitude_destination.fillna(0)
fw.destination_Longitude = fw.destination_Longitude.fillna(0) + fw.Longitude_destination.fillna(0)

# %%
# drop duplicated columns
fw = fw.drop(['ident_origin', 'ident_destination', 'Latitude_origin', 'Longitude_origin', 'Latitude_destination', 'Longitude_destination'], axis=1)

# %%
fw.head()
# Out:
#   tail_number       date aircraft           origin  \
# 0      N7025P  28-Feb-21     None         Bend, OR
# 1      N7025P  28-Feb-21     None  Tews Fld (CA53)
# 2      N7025P  21-Feb-21     None      Lincoln, CA
# 3      N7025P  21-Feb-21     None    Red Bluff, CA
# 4      N7025P  24-Dec-20     None    Red Bluff, CA
#
#                  origin_location          destination  \
# 0          L 43.95194 -121.28694                  NaN
# 1  Tews Fld (Redding, CA) - CA53             Bend, OR
# 2          L 38.93333 -121.41667  Redding Muni (KRDD)
# 3          L 40.24000 -122.19083       Marysville, CA
# 4          L 40.28861 -122.05861     Emigrant Gap, CA
#
#                 destination_location    departure      arrival duration  \
# 0                               None  04:59PM PST          NaN     None
# 1              L 43.81944 -121.37583  01:36PM PST  03:01PM PST     1:24
# 2  Redding Muni (Redding, CA) - KRDD  03:02PM PST  03:49PM PST     0:47
# 3              L 38.94750 -121.52250  12:46PM PST  01:20PM PST     0:33
# 4              L 39.77972 -120.52333  09:25AM PST  10:02AM PST     0:36
#
#                                      medical_service  origin_Latitude  \
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...        43.951940
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...        40.672501
# 2  A PRECIOUS LIFE FLIGHT LLC                    ...        38.933330
# 3  A PRECIOUS LIFE FLIGHT LLC                    ...        40.240000
# 4  A PRECIOUS LIFE FLIGHT LLC                    ...        40.288610
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0       -121.286940              0.000000               0.000000
# 1       -122.342003             43.819440            -121.375830
# 2       -121.416670             40.508999            -122.292999
# 3       -122.190830             38.947500            -121.522500
# 4       -122.058610             39.779720            -120.523330
#
#   ICAO_code_origin ICAO_code_destination iata_code_origin  \
# 0              NaN                  None              NaN
# 1             CA53                   NaN              NaN
# 2              NaN                  KRDD              NaN
# 3              NaN                   NaN              NaN
# 4              NaN                   NaN              NaN
#
#   iata_code_destination
# 0                   NaN
# 1                   NaN
# 2                   RDD
# 3                   NaN
# 4                   NaN

# %%
# load airport data
airports = pd.read_csv("..//Datasets/Airports/BTS_Airports_LAT_LON.csv")

# %%
airports.head()
# Out:
#   AIRPORT_CODE             AIRPORT_NAME              CITY_NAME   COUNTRY_NAME  \
# 0          01A     Afognak Lake Airport      Afognak Lake - AK  United States
# 1          03A  Bear Creek Mining Strip  Granite Mountain - AK  United States
# 2          04A          Lik Mining Camp               Lik - AK  United States
# 3          05A     Little Squaw Airport      Little Squaw - AK  United States
# 4          06A             Kizhuyak Bay          Kizhuyak - AK  United States
#
#   STATE_NAME STATE_CODE   LATITUDE   LONGITUDE
# 0     Alaska         AK  58.109444 -152.906667
# 1     Alaska         AK  65.548056 -161.071667
# 2     Alaska         AK  68.083333 -163.166667
# 3     Alaska         AK  67.570000 -148.183889
# 4     Alaska         AK  57.745278 -152.882778

# %%
# replace abbreviations to full name for the best matching
fw = fw.replace(regex={r'Muni': 'Municipal', r'Rgnl':'Regional', r'Intl':'International', r"Int'l":'International',
                 r'Trml':'Terminal', r'Fld':'Field'})

# %%
# split states fot the best matching
fw['origin_state'] = fw.origin.str.split(', ', n=1, expand=True)[1]
fw.loc[fw.origin_state.isna(), 'origin_state'] = fw.origin_location.str.split(', ', n=1, expand=True)[1].str.rsplit(') ', n=1, expand=True)[0]

fw['destination_state'] = fw.destination.str.split(', ', n=1, expand=True)[1]
fw.loc[fw.destination_state.isna(), 'destination_state'] = fw.destination_location.str.split(', ', n=1, expand=True)[1].str.rsplit(') ', n=1, expand=True)[0]

# %%
# replace location back to NA for the best matching
fw.loc[fw.origin_Latitude == 0, 'origin_Latitude'] = np.nan
fw.loc[fw.origin_Longitude == 0, 'origin_Longitude'] = np.nan

fw.loc[fw.destination_Latitude == 0, 'destination_Latitude'] = np.nan
fw.loc[fw.destination_Longitude == 0, 'destination_Longitude'] = np.nan

# %%
fw.head()
# Out:
#   tail_number       date aircraft             origin  \
# 0      N7025P  28-Feb-21     None           Bend, OR
# 1      N7025P  28-Feb-21     None  Tews Field (CA53)
# 2      N7025P  21-Feb-21     None        Lincoln, CA
# 3      N7025P  21-Feb-21     None      Red Bluff, CA
# 4      N7025P  24-Dec-20     None      Red Bluff, CA
#
#                    origin_location               destination  \
# 0            L 43.95194 -121.28694                       NaN
# 1  Tews Field (Redding, CA) - CA53                  Bend, OR
# 2            L 38.93333 -121.41667  Redding Municipal (KRDD)
# 3            L 40.24000 -122.19083            Marysville, CA
# 4            L 40.28861 -122.05861          Emigrant Gap, CA
#
#                      destination_location    departure      arrival duration  \
# 0                                    None  04:59PM PST          NaN     None
# 1                   L 43.81944 -121.37583  01:36PM PST  03:01PM PST     1:24
# 2  Redding Municipal (Redding, CA) - KRDD  03:02PM PST  03:49PM PST     0:47
# 3                   L 38.94750 -121.52250  12:46PM PST  01:20PM PST     0:33
# 4                   L 39.77972 -120.52333  09:25AM PST  10:02AM PST     0:36
#
#                                      medical_service  origin_Latitude  \
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...        43.951940
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...        40.672501
# 2  A PRECIOUS LIFE FLIGHT LLC                    ...        38.933330
# 3  A PRECIOUS LIFE FLIGHT LLC                    ...        40.240000
# 4  A PRECIOUS LIFE FLIGHT LLC                    ...        40.288610
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0       -121.286940                   NaN                    NaN
# 1       -122.342003             43.819440            -121.375830
# 2       -121.416670             40.508999            -122.292999
# 3       -122.190830             38.947500            -121.522500
# 4       -122.058610             39.779720            -120.523330
#
#   ICAO_code_origin ICAO_code_destination iata_code_origin  \
# 0              NaN                  None              NaN
# 1             CA53                   NaN              NaN
# 2              NaN                  KRDD              NaN
# 3              NaN                   NaN              NaN
# 4              NaN                   NaN              NaN
#
#   iata_code_destination origin_state destination_state
# 0                   NaN           OR              None
# 1                   NaN           CA                OR
# 2                   RDD           CA                CA
# 3                   NaN           CA                CA
# 4                   NaN           CA                CA

# %%
# fuzzy merge on locations with origin airports
fw = fuzzymatcher.fuzzy_left_join(fw, airports.add_suffix('_origin'), left_on = ['origin_state', 'origin_Latitude', 'origin_Longitude', 'origin'], 
                                  right_on = ['STATE_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin','AIRPORT_NAME_origin']).iloc[:,3:].reset_index(drop=True)

# %%
# drop LONGITUDE_origin mismatching
fw.loc[(fw.LONGITUDE_origin > 0) & (fw.origin_state.notnull()) & (fw.destination_state.notnull()), 
       ['AIRPORT_CODE_origin', 'AIRPORT_NAME_origin', 'CITY_NAME_origin', 'COUNTRY_NAME_origin', 
        'STATE_NAME_origin', 'STATE_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin']] = np.nan

# %%
# drop origin_state mismatching
fw.loc[(fw.origin_state != fw.STATE_CODE_origin) & (fw.STATE_CODE_origin.notnull()), 
       ['AIRPORT_CODE_origin', 'AIRPORT_NAME_origin', 'CITY_NAME_origin', 'COUNTRY_NAME_origin', 
        'STATE_NAME_origin', 'STATE_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin']] = np.nan

# %%
# replace null values in iata_code_origin
fw.loc[fw.iata_code_origin.isna(),'iata_code_origin']  = fw.loc[fw.iata_code_origin.isna(), 'AIRPORT_CODE_origin']

# %%
# fuzzy merge on locations with destination airports
fw = fuzzymatcher.fuzzy_left_join(fw, airports.add_suffix('_destination'), left_on = ['destination_state', 'destination_Latitude', 'destination_Longitude', 'destination'], 
                                  right_on = ['STATE_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination','AIRPORT_NAME_destination']).iloc[:,3:].reset_index(drop=True)

# %%
# drop LONGITUDE_destination mismatching
fw.loc[(fw.LONGITUDE_destination > 0) & (fw.origin_state.notnull()) & (fw.destination_state.notnull()), 
       ['AIRPORT_CODE_destination', 'AIRPORT_NAME_destination', 'CITY_NAME_destination', 'COUNTRY_NAME_destination', 
        'STATE_NAME_destination', 'STATE_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination']] = np.nan

# %%
# drop destination_state mismatching
fw.loc[(fw.destination_state != fw.STATE_CODE_destination) & (fw.STATE_CODE_destination.notnull()), 
       ['AIRPORT_CODE_destination', 'AIRPORT_NAME_destination', 'CITY_NAME_destination', 'COUNTRY_NAME_destination', 
        'STATE_NAME_destination', 'STATE_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination']] = np.nan

# %%
# replace null values in iata_code_destination
fw.loc[fw.iata_code_destination.isna(),'iata_code_destination']  = fw.loc[fw.iata_code_destination.isna(), 'AIRPORT_CODE_destination']

# %%
# drop duplicated rows
fw = fw.drop(['STATE_CODE_origin', 'AIRPORT_CODE_origin', 'LATITUDE_origin', 'LONGITUDE_origin'], axis=1)
fw = fw.drop(['STATE_CODE_destination', 'AIRPORT_CODE_destination', 'LATITUDE_destination', 'LONGITUDE_destination'], axis=1)

# %%
# rearrange for convenience
fw = fw.iloc[:,:15].join([fw.iloc[:,15], fw.iloc[:,17], fw.iloc[:, 21:25], fw.iloc[:,19],
                    fw.iloc[:,16], fw.iloc[:,18], fw.iloc[:, 25:29], fw.iloc[:,20]])

# %%
# complete origin ICAO codes
fw = fw.merge(airport_codes.drop_duplicates(subset=['iata_code'])[['iata_code','ident']], how='left', left_on='iata_code_origin', right_on='iata_code')
fw.loc[(fw.ICAO_code_origin.isna()) & (fw.iata_code_origin.notnull()), 'ICAO_code_origin'] = fw.loc[:,'ident']
fw = fw.drop(['ident','iata_code'], axis=1)

# %%
# complete destination ICAO codes
fw = fw.merge(airport_codes.drop_duplicates(subset=['iata_code'])[['iata_code','ident']], how='left', left_on='iata_code_destination', right_on='iata_code')
fw.loc[(fw.ICAO_code_destination.isna()) & (fw.iata_code_destination.notnull()), 'ICAO_code_destination'] = fw.loc[:,'ident']
fw = fw.drop(['ident','iata_code'], axis=1)

# %%
fw
# Out:
#       tail_number       date aircraft                        origin  \
# 0          N7025P  28-Feb-21     None                      Bend, OR
# 1          N7025P  28-Feb-21     None             Tews Field (CA53)
# 2          N7025P  21-Feb-21     None                   Lincoln, CA
# 3          N7025P  21-Feb-21     None                 Red Bluff, CA
# 4          N7025P  24-Dec-20     None                 Red Bluff, CA
# ...           ...        ...      ...                           ...
# 11236      N977TC  30-Nov-20     C680  El Paso International (KELP)
# 11237      N977TC  30-Nov-20     C680        William P Hobby (KHOU)
# 11238      N102WK  12-Feb-21     BE9T                 Smyrna (KMQY)
# 11239      N102WK  28-Jan-21     BE9T    Shreveport Regional (KSHV)
# 11240      N102WK   5-Jan-21     BE9T    Shreveport Regional (KSHV)
#
#                                    origin_location  \
# 0                            L 43.95194 -121.28694
# 1                  Tews Field (Redding, CA) - CA53
# 2                            L 38.93333 -121.41667
# 3                            L 40.24000 -122.19083
# 4                            L 40.28861 -122.05861
# ...                                            ...
# 11236   El Paso International (El Paso, TX) - KELP
# 11237         William P Hobby (Houston, TX) - KHOU
# 11238                   Smyrna (Smyrna, TN) - KMQY
# 11239  Shreveport Regional (Shreveport, LA) - KSHV
# 11240  Shreveport Regional (Shreveport, LA) - KSHV
#
#                         destination  \
# 0                               NaN
# 1                          Bend, OR
# 2          Redding Municipal (KRDD)
# 3                    Marysville, CA
# 4                  Emigrant Gap, CA
# ...                             ...
# 11236        William P Hobby (KHOU)
# 11237  El Paso International (KELP)
# 11238    Shreveport Regional (KSHV)
# 11239                 Smyrna (KMQY)
# 11240    Shreveport Regional (KSHV)
#
#                               destination_location    departure      arrival  \
# 0                                             None  04:59PM PST          NaN
# 1                            L 43.81944 -121.37583  01:36PM PST  03:01PM PST
# 2           Redding Municipal (Redding, CA) - KRDD  03:02PM PST  03:49PM PST
# 3                            L 38.94750 -121.52250  12:46PM PST  01:20PM PST
# 4                            L 39.77972 -120.52333  09:25AM PST  10:02AM PST
# ...                                            ...          ...          ...
# 11236         William P Hobby (Houston, TX) - KHOU  03:30PM MST  05:54PM CST
# 11237   El Paso International (El Paso, TX) - KELP  11:11AM CST  11:52AM MST
# 11238  Shreveport Regional (Shreveport, LA) - KSHV  11:19AM CST  01:34PM CST
# 11239                   Smyrna (Smyrna, TN) - KMQY  12:30PM CST  02:25PM CST
# 11240  Shreveport Regional (Shreveport, LA) - KSHV  09:24AM CST  10:19AM CST
#
#       duration                                    medical_service  \
# 0         None  A PRECIOUS LIFE FLIGHT LLC                    ...
# 1         1:24  A PRECIOUS LIFE FLIGHT LLC                    ...
# 2         0:47  A PRECIOUS LIFE FLIGHT LLC                    ...
# 3         0:33  A PRECIOUS LIFE FLIGHT LLC                    ...
# 4         0:36  A PRECIOUS LIFE FLIGHT LLC                    ...
# ...        ...                                                ...
# 11236     1:23  TEXAS CHILDRENS HOSPITAL                      ...
# 11237     1:40  TEXAS CHILDRENS HOSPITAL                      ...
# 11238     2:14  WILLIS KNIGHTON MEDICAL CENTER                ...
# 11239     1:55  WILLIS KNIGHTON MEDICAL CENTER                ...
# 11240     0:55  WILLIS KNIGHTON MEDICAL CENTER                ...
#
#        origin_Latitude  origin_Longitude  destination_Latitude  \
# 0            43.951940       -121.286940                   NaN
# 1            40.672501       -122.342003             43.819440
# 2            38.933330       -121.416670             40.508999
# 3            40.240000       -122.190830             38.947500
# 4            40.288610       -122.058610             39.779720
# ...                ...               ...                   ...
# 11236        31.807199       -106.377998             29.645399
# 11237        29.645399        -95.278900             31.807199
# 11238        36.008999        -86.520103             32.446602
# 11239        32.446602        -93.825600             36.008999
# 11240        32.446602        -93.825600             32.446602
#
#        destination_Longitude ICAO_code_origin iata_code_origin  \
# 0                        NaN              NaN              OR4
# 1                -121.375830             CA53              O85
# 2                -122.292999             KSMF              SMF
# 3                -121.522500             KRBL              RBL
# 4                -120.523330             KRBL              RBL
# ...                      ...              ...              ...
# 11236             -95.278900             KELP              ELP
# 11237            -106.377998             KHOU              HOU
# 11238             -93.825600             KMQY              MQY
# 11239             -86.520103             KSHV              SHV
# 11240             -93.825600             KSHV              SHV
#
#             AIRPORT_NAME_origin CITY_NAME_origin COUNTRY_NAME_origin  \
# 0                Bend Municipal        Bend - OR       United States
# 1                  Benton Field     Redding - CA       United States
# 2      Sacramento International  Sacramento - CA       United States
# 3           Red Bluff Municipal   Red Bluff - CA       United States
# 4           Red Bluff Municipal   Red Bluff - CA       United States
# ...                         ...              ...                 ...
# 11236     El Paso International     El Paso - TX       United States
# 11237           William P Hobby     Houston - TX       United States
# 11238            Smyrna Airport      Smyrna - TN       United States
# 11239       Shreveport Regional  Shreveport - LA       United States
# 11240       Shreveport Regional  Shreveport - LA       United States
#
#       STATE_NAME_origin origin_state ICAO_code_destination  \
# 0                Oregon           OR                  None
# 1            California           CA                   NaN
# 2            California           CA                  KRDD
# 3            California           CA                   NaN
# 4            California           CA                   NaN
# ...                 ...          ...                   ...
# 11236             Texas           TX                  KHOU
# 11237             Texas           TX                  KELP
# 11238         Tennessee           TN                  KSHV
# 11239         Louisiana           LA                  KMQY
# 11240         Louisiana           LA                  KSHV
#
#       iata_code_destination  AIRPORT_NAME_destination CITY_NAME_destination  \
# 0                       NaN                       NaN                   NaN
# 1                       OR4            Bend Municipal             Bend - OR
# 2                       RDD         Redding Municipal          Redding - CA
# 3                       SMF  Sacramento International       Sacramento - CA
# 4                       NaN                       NaN                   NaN
# ...                     ...                       ...                   ...
# 11236                   HOU           William P Hobby          Houston - TX
# 11237                   ELP     El Paso International          El Paso - TX
# 11238                   SHV       Shreveport Regional       Shreveport - LA
# 11239                   MQY            Smyrna Airport           Smyrna - TN
# 11240                   SHV       Shreveport Regional       Shreveport - LA
#
#       COUNTRY_NAME_destination STATE_NAME_destination destination_state
# 0                          NaN                    NaN              None
# 1                United States                 Oregon                OR
# 2                United States             California                CA
# 3                United States             California                CA
# 4                          NaN                    NaN                CA
# ...                        ...                    ...               ...
# 11236            United States                  Texas                TX
# 11237            United States                  Texas                TX
# 11238            United States              Louisiana                LA
# 11239            United States              Tennessee                TN
# 11240            United States              Louisiana                LA
#
# [11241 rows x 29 columns]

# %%
fw.to_csv('..//Datasets/29Nov20-28Feb21/FW_with_airports(29Nov20-28Feb21 revised).csv', index=False)
