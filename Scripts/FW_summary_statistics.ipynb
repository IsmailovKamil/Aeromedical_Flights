# %%
#load packages
import pandas as pd 
import xlsxwriter

# %%
#load data and convert dates to datetime
fw = pd.read_csv("../Datasets/FW/FW_tail_numbers(cleaned).csv", encoding='latin-1', parse_dates=['dates'])

# %%
#inspect data
fw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13031 entries, 0 to 13030
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tail_number  13031 non-null  object
#  1   dates        13031 non-null  datetime64[ns]
#  2   aircraft     13005 non-null  object
#  3   origin       13030 non-null  object
#  4   destination  13031 non-null  object
#  5   departure    13031 non-null  object
#  6   arrival      12788 non-null  object
#  7   duration     12783 non-null  object
#  8   NAME         13031 non-null  object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 916.4+ KB

# %%
#glimpse to data 
fw.head()
# Out:
#   tail_number      dates aircraft              origin            destination  \
# 0      N7025P 2020-12-24      NaN  Near Red Bluff, CA  Near Emigrant Gap, CA
# 1      N7025P 2020-11-27      NaN        Redding Muni         Near Chico, CA
# 2      N269GJ 2020-12-18     LJ60         Aurora Muni   Fort Lauderdale Exec
# 3      N888CP 2021-02-11     LJ31         Aurora Muni            Aurora Muni
# 4      N888CP 2021-01-24     LJ31   Akron-Canton Rgnl            Aurora Muni
#
#      departure      arrival duration  \
# 0  09:25AM PST  10:02AM PST     0:36
# 1  11:26AM PST  11:42AM PST     0:16
# 2  08:53AM CST  12:20PM EST     2:26
# 3  10:32AM CST  11:25AM CST     0:53
# 4  04:41PM EST  04:58PM CST     1:17
#
#                                                 NAME
# 0  A PRECIOUS LIFE FLIGHT LLC                    ...
# 1  A PRECIOUS LIFE FLIGHT LLC                    ...
# 2  AEROCARE MEDICAL TRANSPORT SYSTEM INC         ...
# 3  AEROCARE MEDICAL TRANSPORT SYSTEMS INC        ...
# 4  AEROCARE MEDICAL TRANSPORT SYSTEMS INC        ...

# %%
#chech for null values
fw.isna().sum()
# Out:
# tail_number      0
# dates            0
# aircraft        26
# origin           1
# destination      0
# departure        0
# arrival        243
# duration       248
# NAME             0
# dtype: int64

# %%
#the null duration indicates that the flight was canceled or diverted. So, let's remove it 
fw = fw.dropna(subset=['duration'])

# %%
# drop flight that was just scheduled 
fw = fw.query("duration != 'Scheduled'")

# %%
# convert duration to minutes and add a new column 
fw['duration_minutes'] = pd.to_datetime(fw.duration, format="%H:%M").dt.hour * 60 + pd.to_datetime(fw.duration, format="%H:%M").dt.minute

# convert duration to the H:M format
fw.duration = pd.to_datetime(fw.duration, format="%H:%M").dt.time

#rearrange data for the convenience
fw = fw.iloc[:,:8].join([fw.iloc[:,-1], fw.loc[:,'NAME']])

# %%
# !!!# let's consider flights which more or equal 5 minutes. We don't think that flight that less than 5 minutes has any sense.
fw = fw.query("duration_minutes >= 5")

# %%
# total number of flights by each service and its tail number 
total_flights = pd.DataFrame(fw.groupby("NAME").tail_number.value_counts()).rename({'tail_number':'Number of Flights'}, axis=1)

# Average Flights per Day
avg_total_flights = pd.Series(fw.groupby("NAME").tail_number.value_counts().sort_index() / fw.groupby(['NAME','tail_number']).dates.nunique(), name='Average Flights per Day')

# %%
stats = fw.groupby(["NAME", 'tail_number']).duration_minutes.agg(['sum','mean', 'median', 'max', 'min'])\
          .rename({'sum':'Total Duration(min)', 'mean':'Average Duration(min)', 'median':'Median Duration(min)', 'max':'MAX Duration(min)', 'min':'MIN Duration(min)'}, axis=1)

# %%
#total summary statistics 
total_stats = total_flights.join([avg_total_flights, stats])
total_stats.head()
# Out:
#                                                                 Number of Flights  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                       2
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                       1
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                     110
# AEROMED TRANSPORT CO LLC                           N80YD                       43
# AIR AMBULANCE BY AIR TREK INC                      N644AT                      96
#
#                                                                 Average Flights per Day  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                      1.000000
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                      1.000000
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                      3.055556
# AEROMED TRANSPORT CO LLC                           N80YD                       1.592593
# AIR AMBULANCE BY AIR TREK INC                      N644AT                      2.526316
#
#                                                                 Total Duration(min)  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                        52
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                       146
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                      7525
# AEROMED TRANSPORT CO LLC                           N80YD                       2489
# AIR AMBULANCE BY AIR TREK INC                      N644AT                      8247
#
#                                                                 Average Duration(min)  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                   26.000000
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                  146.000000
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                   68.409091
# AEROMED TRANSPORT CO LLC                           N80YD                    57.883721
# AIR AMBULANCE BY AIR TREK INC                      N644AT                   85.906250
#
#                                                                 Median Duration(min)  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                       26.0
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                      146.0
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                       45.0
# AEROMED TRANSPORT CO LLC                           N80YD                        50.0
# AIR AMBULANCE BY AIR TREK INC                      N644AT                       86.5
#
#                                                                 MAX Duration(min)  \
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                      36
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                     146
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                     224
# AEROMED TRANSPORT CO LLC                           N80YD                      263
# AIR AMBULANCE BY AIR TREK INC                      N644AT                     190
#
#                                                                 MIN Duration(min)
# NAME                                               tail_number
# A PRECIOUS LIFE FLIGHT LLC                         N7025P                      16
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ                     146
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP                       9
# AEROMED TRANSPORT CO LLC                           N80YD                        5
# AIR AMBULANCE BY AIR TREK INC                      N644AT                       9

# %%
# Origins (where does the flight start each time)
Origins = pd.DataFrame(fw.groupby(['NAME', 'tail_number']).origin.value_counts()).rename({'origin':'Number of Flights'}, axis=1)
Origins.head()
# Out:
#                                                                                     Number of Flights
# NAME                                               tail_number origin
# A PRECIOUS LIFE FLIGHT LLC                         N7025P      Near Red Bluff, CA                   1
#                                                                Redding Muni                         1
# AEROCARE MEDICAL TRANSPORT SYSTEM INC              N269GJ      Aurora Muni                          1
# AEROCARE MEDICAL TRANSPORT SYSTEMS INC             N888CP      Aurora Muni                         34
#                                                                Chicago Midway Intl                 23

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('..//Datasets/FW/FW_stats.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet.
total_stats.to_excel(writer, sheet_name='stats')
Origins.to_excel(writer, sheet_name='origin')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
